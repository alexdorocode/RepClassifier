# %% [markdown]
# # **Predictor Básico de Proteínas Moonlighting**
# En este notebook, construiremos y entrenaremos un clasificador para secuencias de proteínas moonlighting utilizando el modelo ProstT5. Nuestro objetivo es demostrar cómo el deep learning puede ser utilizado para clasificar secuencias basadas en sus anotaciones funcionales. Este ejercicio servirá como una introducción al manejo de datos de proteínas y a la aplicación de técnicas avanzadas de procesamiento de lenguaje natural en bioinformática, específicamente para proteínas moonlighting.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from transformers import T5Tokenizer, T5EncoderModel
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score
import seaborn as sns

import torch.optim as optim

# Verificamos si CUDA está disponible; si no lo está, lanzamos una excepción
# para garantizar que el script se ejecute en una GPU.
if not torch.cuda.is_available():
    raise Exception("CUDA no está disponible. Este script requiere una GPU con CUDA para un procesamiento eficiente.")
device = torch.device("cuda")

# %% [markdown]
# ## Clasificador de proteínas
# Nuestro clasificador de proteínas está diseñado como un modelo secuencial que utiliza embeddings de secuencias proteicas, procesándolos a través de varias capas para predecir si una secuencia es moonlighting o no.
#
# Nota: los embeddings son representaciones numéricas densas que capturan características relevantes de los datos en un espacio de menor dimensión.

# %%
class ProteinClassifier(nn.Module):
    def __init__(self):
        super(ProteinClassifier, self).__init__()
        # Definimos la arquitectura del clasificador.
        self.classifier = nn.Sequential(
            nn.Linear(1024, 128),  # Tamaño de entrada basada en el embedding T5.
            nn.ReLU(),             # Función de activación para añadir no linealidad.
            nn.Dropout(0.1),       # Capa de dropout para reducir el sobreajuste,
            nn.Linear(128, 1)      # Salida binaria para la clasificación.
        ).to(device)  # Garantizamos que el modelo use la GPU.

    def forward(self, embeddings):
        # Pasamos los embeddings por el clasificador para obtener los logits
        # (valores de salida sin normalizar de un modelo antes de aplicar una
        # función de activación como softmax).
        logits = self.classifier(embeddings)
        return logits

# %% [markdown]
# ## Manejo de datos
# Para entrenar y evaluar nuestro modelo, cargaremos datos desde un archivo CSV, los dividiremos en conjuntos de entrenamiento y prueba, y crearemos nuestros objetos de dataset. La clase `ProteinDataset` se encarga de procesar y tokenizar las secuencias de proteínas, generar embeddings con el modelo ProstT5, y almacenar los embeddings resultantes junto con sus etiquetas correspondientes.

# %%
class ProteinDataset(Dataset):
    def __init__(self, dataframe, model_name='Rostlab/ProstT5', device='cpu', mode='seq'):
        self.dataframe = dataframe
        self.embeddings = []
        self.labels = []
        tokenizer = T5Tokenizer.from_pretrained(model_name, do_lower_case=False)
        model = T5EncoderModel.from_pretrained(model_name).to(device)
        model.eval()

        with torch.no_grad():
            for _, row in dataframe.iterrows():
                sequence = row[mode]
                label = row['Class']

                # Preprocesamiento y tokenización.
                sequence_processed = " ".join(list(re.sub(r"[UZOB]", "X", sequence)))
                sequence_processed = "<AA2fold> " + sequence_processed if sequence_processed.isupper() else "<fold2AA> " + sequence_processed
                inputs = tokenizer(sequence_processed, return_tensors="pt", padding=True, truncation=True,
                                   max_length=512, add_special_tokens=True).to(device)

                # Generación de embeddings.
                outputs = model(input_ids=inputs.input_ids, attention_mask=inputs.attention_mask)
                embeddings = outputs.last_hidden_state.mean(dim=1)

                self.embeddings.append(embeddings.cpu().numpy())  # Almacenado como numpy para reducir el uso de memoria.
                self.labels.append(label)

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        # Convertir de numpy a tensor cuando se accede.
        return torch.tensor(self.embeddings[idx]), torch.tensor(self.labels[idx], dtype=torch.float)

# %% [markdown]
# ## Preparación del Conjunto de Datos
# En esta sección, preparamos el conjunto de datos y definimos las secuencias de aminoácidos que analizaremos. Este proceso generará embeddings, lo cual puede llevar unos minutos.
#
# Primero, seleccionamos las secuencias de interés. Luego, creamos los conjuntos de datos de entrenamiento y prueba, y preparamos los cargadores de datos para el entrenamiento y evaluación del modelo.

# %%
df_literature = pd.read_csv('/content/drive/My Drive/predictor_dataset.csv')
mode = "Amino Acid Sequence"

## Aquí puedes estratificar.
df_train, df_test = train_test_split(df_literature, test_size=0.2, random_state=42, stratify=df_literature['Class'])
train_dataset = ProteinDataset(df_train, mode=mode, device=device)
test_dataset = ProteinDataset(df_test, mode=mode, device=device)

# Creamos los cargadores de datos.
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.60k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/11.3G [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ## Bucle de entrenamiento
# En esta sección, realizaremos el entrenamiento de nuestro clasificador de proteínas a través de múltiples épocas. Seguiremos con una fase de validación para monitorear el rendimiento del modelo en datos no vistos. El siguiente bloque de código detalla el bucle completo de entrenamiento y validación, incluyendo el seguimiento de la pérdida y precisión en ambas fases a lo largo de las épocas.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

def setup_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = ProteinClassifier().to(device)
    optimizer = optim.Adam(model.parameters(), lr=5e-5)
    loss_fn = nn.BCEWithLogitsLoss()
    return model, optimizer, loss_fn, device

def train_one_epoch(model, dataloader, optimizer, loss_fn, device):
    model.train()
    total_loss, correct_predictions, total_predictions = 0, 0, 0
    for sequences, labels in dataloader:
        sequences, labels = sequences.to(device), labels.to(device).float().unsqueeze(-1)
        optimizer.zero_grad()
        logits = model(sequences).squeeze(-1)
        loss = loss_fn(logits, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        preds = torch.sigmoid(logits) >= 0.5
        correct_predictions += (preds == labels.bool()).sum().item()
        total_predictions += labels.size(0)
    avg_loss = total_loss / len(dataloader)
    accuracy = correct_predictions / total_predictions
    return avg_loss, accuracy

def validate_one_epoch(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct_predictions, total_predictions = 0, 0, 0
    with torch.no_grad():
        for sequences, labels in dataloader:
            sequences, labels = sequences.to(device), labels.to(device).float().unsqueeze(-1)
            logits = model(sequences).squeeze(-1)
            loss = loss_fn(logits, labels)
            total_loss += loss.item()
            preds = torch.sigmoid(logits) >= 0.5
            correct_predictions += (preds == labels.bool()).sum().item()
            total_predictions += labels.size(0)
    avg_loss = total_loss / len(dataloader)
    accuracy = correct_predictions / total_predictions
    return avg_loss, accuracy

def train_and_validate(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, num_epochs):
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    for epoch in range(num_epochs):
        train_loss, train_accuracy = train_one_epoch(model, train_dataloader, optimizer, loss_fn, device)
        val_loss, val_accuracy = validate_one_epoch(model, test_dataloader, loss_fn, device)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        print(f'Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, '
              f'Training Accuracy: {train_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}')
    return train_losses, val_losses, train_accuracies, val_accuracies

def plot_results(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(16, 8))

    # Gráfico de pérdidas
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss', fontsize=22)
    plt.xlabel('Epochs', fontsize=20)
    plt.ylabel('Loss', fontsize=20)
    plt.legend(fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

    # Gráfico de precisión
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy', fontsize=22)
    plt.xlabel('Epochs', fontsize=20)
    plt.ylabel('Accuracy', fontsize=20)
    plt.legend(fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

    plt.tight_layout()
    plt.show()

def evaluate_and_plot_confusion_matrix(model, dataloader, device):
    model.eval()  # Configuramos el modelo para modo de evaluación.
    all_preds, all_labels = [], []

    with torch.no_grad():
        for sequences, labels in dataloader:
            sequences = sequences.to(device)
            labels = labels.to(device).float().unsqueeze(-1)
            logits = model(sequences).squeeze(-1)
            preds = torch.sigmoid(logits) >= 0.5  # Convertimos los logits a predicciones binarias.

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Generamos la matriz de confusión.
    cm = confusion_matrix(all_labels, all_preds)
    tn, fp, fn, tp = cm.ravel()

    # Calculamos la especificidad.
    specificity = tn / (tn + fp)

    # Calculamos el estadístico Kappa.
    kappa = cohen_kappa_score(all_labels, all_preds)

    # Representamos la matriz de confusión.
    plt.figure(figsize=(12, 8))  # Aumenta el tamaño de la figura
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'],
                annot_kws={"size": 24})
    plt.xlabel('Predicted Label', fontsize=20)
    plt.ylabel('True Label', fontsize=20)
    plt.title('Confusion Matrix', fontsize=22)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.show()

    # Cálculo de métricas adicionales para evaluar el modelo.
    metrics = classification_report(all_labels, all_preds, target_names=['Negative', 'Positive'])
    print("\nMétricas de Evaluación:")
    print(metrics)
    print(f"Especificidad: {specificity:.4f}")
    print(f"Estadístico Kappa: {kappa:.4f}")

# %% [markdown]
# ### Entrenamiento y evaluación del modelo
# Inicializamos el modelo, configuramos el optimizador y la función de pérdida, y realizamos el entrenamiento y validación del modelo a lo largo de múltiples épocas. Al finalizar, visualizamos los resultados obtenidos mediante gráficos de pérdidas y precisiones, complementados con una matriz de confusión para evaluar el rendimiento del modelo.

# %%
# Código principal.
model, optimizer, loss_fn, device = setup_model()
num_epochs = 200
train_losses, val_losses, train_accuracies, val_accuracies = train_and_validate(model,  train_dataloader,test_dataloader, optimizer, loss_fn, device, num_epochs)
plot_results(train_losses, val_losses, train_accuracies, val_accuracies)
evaluate_and_plot_confusion_matrix(model, test_dataloader, device)
# Out:
# Epoch 1, Training Loss: 0.6965, Validation Loss: 0.6936, Training Accuracy: 0.4444, Validation Accuracy: 0.4545
# Epoch 2, Training Loss: 0.6886, Validation Loss: 0.6876, Training Accuracy: 0.5565, Validation Accuracy: 0.5534
# Epoch 3, Training Loss: 0.6803, Validation Loss: 0.6808, Training Accuracy: 0.6538, Validation Accuracy: 0.6047
# Epoch 4, Training Loss: 0.6716, Validation Loss: 0.6735, Training Accuracy: 0.6825, Validation Accuracy: 0.6285
# Epoch 5, Training Loss: 0.6621, Validation Loss: 0.6662, Training Accuracy: 0.6726, Validation Accuracy: 0.6482
# Epoch 6, Training Loss: 0.6528, Validation Loss: 0.6589, Training Accuracy: 0.6776, Validation Accuracy: 0.6403
# Epoch 7, Training Loss: 0.6428, Validation Loss: 0.6514, Training Accuracy: 0.6885, Validation Accuracy: 0.6482
# Epoch 8, Training Loss: 0.6338, Validation Loss: 0.6449, Training Accuracy: 0.6865, Validation Accuracy: 0.6561
# Epoch 9, Training Loss: 0.6256, Validation Loss: 0.6395, Training Accuracy: 0.6885, Validation Accuracy: 0.6561
# Epoch 10, Training Loss: 0.6187, Validation Loss: 0.6343, Training Accuracy: 0.6915, Validation Accuracy: 0.6601
# Epoch 11, Training Loss: 0.6110, Validation Loss: 0.6306, Training Accuracy: 0.6885, Validation Accuracy: 0.6640
# Epoch 12, Training Loss: 0.6044, Validation Loss: 0.6257, Training Accuracy: 0.6935, Validation Accuracy: 0.6640
# Epoch 13, Training Loss: 0.5992, Validation Loss: 0.6238, Training Accuracy: 0.6994, Validation Accuracy: 0.6640
# Epoch 14, Training Loss: 0.5947, Validation Loss: 0.6182, Training Accuracy: 0.6954, Validation Accuracy: 0.6719
# Epoch 15, Training Loss: 0.5900, Validation Loss: 0.6168, Training Accuracy: 0.7103, Validation Accuracy: 0.6759
# Epoch 16, Training Loss: 0.5853, Validation Loss: 0.6136, Training Accuracy: 0.7063, Validation Accuracy: 0.6759
# Epoch 17, Training Loss: 0.5831, Validation Loss: 0.6104, Training Accuracy: 0.7054, Validation Accuracy: 0.6759
# Epoch 18, Training Loss: 0.5801, Validation Loss: 0.6124, Training Accuracy: 0.7004, Validation Accuracy: 0.6759
# Epoch 19, Training Loss: 0.5761, Validation Loss: 0.6088, Training Accuracy: 0.7083, Validation Accuracy: 0.6798
# Epoch 20, Training Loss: 0.5736, Validation Loss: 0.6076, Training Accuracy: 0.7093, Validation Accuracy: 0.6838
# Epoch 21, Training Loss: 0.5724, Validation Loss: 0.6040, Training Accuracy: 0.7103, Validation Accuracy: 0.6877
# Epoch 22, Training Loss: 0.5686, Validation Loss: 0.6044, Training Accuracy: 0.7123, Validation Accuracy: 0.6957
# Epoch 23, Training Loss: 0.5675, Validation Loss: 0.6042, Training Accuracy: 0.7173, Validation Accuracy: 0.6877
# Epoch 24, Training Loss: 0.5650, Validation Loss: 0.6017, Training Accuracy: 0.7222, Validation Accuracy: 0.6877
# Epoch 25, Training Loss: 0.5637, Validation Loss: 0.6008, Training Accuracy: 0.7222, Validation Accuracy: 0.6877
# Epoch 26, Training Loss: 0.5621, Validation Loss: 0.5995, Training Accuracy: 0.7183, Validation Accuracy: 0.6877
# Epoch 27, Training Loss: 0.5599, Validation Loss: 0.6003, Training Accuracy: 0.7153, Validation Accuracy: 0.6917
# Epoch 28, Training Loss: 0.5579, Validation Loss: 0.6009, Training Accuracy: 0.7192, Validation Accuracy: 0.6917
# Epoch 29, Training Loss: 0.5568, Validation Loss: 0.5980, Training Accuracy: 0.7202, Validation Accuracy: 0.6957
# Epoch 30, Training Loss: 0.5559, Validation Loss: 0.5974, Training Accuracy: 0.7282, Validation Accuracy: 0.6957
# Epoch 31, Training Loss: 0.5554, Validation Loss: 0.5963, Training Accuracy: 0.7222, Validation Accuracy: 0.6917
# Epoch 32, Training Loss: 0.5541, Validation Loss: 0.5976, Training Accuracy: 0.7252, Validation Accuracy: 0.6957
# Epoch 33, Training Loss: 0.5510, Validation Loss: 0.5946, Training Accuracy: 0.7262, Validation Accuracy: 0.6957
# Epoch 34, Training Loss: 0.5506, Validation Loss: 0.5979, Training Accuracy: 0.7192, Validation Accuracy: 0.6838
# Epoch 35, Training Loss: 0.5496, Validation Loss: 0.5951, Training Accuracy: 0.7232, Validation Accuracy: 0.6877
# Epoch 36, Training Loss: 0.5464, Validation Loss: 0.5969, Training Accuracy: 0.7321, Validation Accuracy: 0.6838
# Epoch 37, Training Loss: 0.5468, Validation Loss: 0.5957, Training Accuracy: 0.7232, Validation Accuracy: 0.6838
# Epoch 38, Training Loss: 0.5451, Validation Loss: 0.5955, Training Accuracy: 0.7262, Validation Accuracy: 0.6877
# Epoch 39, Training Loss: 0.5429, Validation Loss: 0.5911, Training Accuracy: 0.7321, Validation Accuracy: 0.6838
# Epoch 40, Training Loss: 0.5423, Validation Loss: 0.5946, Training Accuracy: 0.7262, Validation Accuracy: 0.6877
# Epoch 41, Training Loss: 0.5412, Validation Loss: 0.5936, Training Accuracy: 0.7242, Validation Accuracy: 0.6798
# Epoch 42, Training Loss: 0.5408, Validation Loss: 0.5942, Training Accuracy: 0.7302, Validation Accuracy: 0.6719
# Epoch 43, Training Loss: 0.5382, Validation Loss: 0.5922, Training Accuracy: 0.7321, Validation Accuracy: 0.6838
# Epoch 44, Training Loss: 0.5365, Validation Loss: 0.5945, Training Accuracy: 0.7272, Validation Accuracy: 0.6798
# Epoch 45, Training Loss: 0.5379, Validation Loss: 0.5908, Training Accuracy: 0.7312, Validation Accuracy: 0.6759
# Epoch 46, Training Loss: 0.5355, Validation Loss: 0.5922, Training Accuracy: 0.7371, Validation Accuracy: 0.6719
# Epoch 47, Training Loss: 0.5350, Validation Loss: 0.5910, Training Accuracy: 0.7232, Validation Accuracy: 0.6759
# Epoch 48, Training Loss: 0.5344, Validation Loss: 0.5911, Training Accuracy: 0.7312, Validation Accuracy: 0.6838
# Epoch 49, Training Loss: 0.5325, Validation Loss: 0.5937, Training Accuracy: 0.7411, Validation Accuracy: 0.6719
# Epoch 50, Training Loss: 0.5309, Validation Loss: 0.5909, Training Accuracy: 0.7371, Validation Accuracy: 0.6680
# Epoch 51, Training Loss: 0.5304, Validation Loss: 0.5898, Training Accuracy: 0.7361, Validation Accuracy: 0.6719
# Epoch 52, Training Loss: 0.5295, Validation Loss: 0.5879, Training Accuracy: 0.7312, Validation Accuracy: 0.6680
# Epoch 53, Training Loss: 0.5292, Validation Loss: 0.5918, Training Accuracy: 0.7391, Validation Accuracy: 0.6640
# Epoch 54, Training Loss: 0.5267, Validation Loss: 0.5894, Training Accuracy: 0.7470, Validation Accuracy: 0.6680
# Epoch 55, Training Loss: 0.5261, Validation Loss: 0.5897, Training Accuracy: 0.7480, Validation Accuracy: 0.6680
# Epoch 56, Training Loss: 0.5258, Validation Loss: 0.5916, Training Accuracy: 0.7401, Validation Accuracy: 0.6601
# Epoch 57, Training Loss: 0.5238, Validation Loss: 0.5904, Training Accuracy: 0.7411, Validation Accuracy: 0.6759
# Epoch 58, Training Loss: 0.5238, Validation Loss: 0.5911, Training Accuracy: 0.7440, Validation Accuracy: 0.6680
# Epoch 59, Training Loss: 0.5222, Validation Loss: 0.5888, Training Accuracy: 0.7421, Validation Accuracy: 0.6917
# Epoch 60, Training Loss: 0.5210, Validation Loss: 0.5897, Training Accuracy: 0.7460, Validation Accuracy: 0.6798
# Epoch 61, Training Loss: 0.5206, Validation Loss: 0.5898, Training Accuracy: 0.7460, Validation Accuracy: 0.6798
# Epoch 62, Training Loss: 0.5194, Validation Loss: 0.5940, Training Accuracy: 0.7490, Validation Accuracy: 0.6877
# Epoch 63, Training Loss: 0.5173, Validation Loss: 0.5874, Training Accuracy: 0.7450, Validation Accuracy: 0.6719
# Epoch 64, Training Loss: 0.5187, Validation Loss: 0.5883, Training Accuracy: 0.7440, Validation Accuracy: 0.6877
# Epoch 65, Training Loss: 0.5161, Validation Loss: 0.5910, Training Accuracy: 0.7460, Validation Accuracy: 0.6798
# Epoch 66, Training Loss: 0.5167, Validation Loss: 0.5893, Training Accuracy: 0.7460, Validation Accuracy: 0.6759
# Epoch 67, Training Loss: 0.5155, Validation Loss: 0.5893, Training Accuracy: 0.7490, Validation Accuracy: 0.6877
# Epoch 68, Training Loss: 0.5149, Validation Loss: 0.5888, Training Accuracy: 0.7470, Validation Accuracy: 0.6877
# Epoch 69, Training Loss: 0.5134, Validation Loss: 0.5887, Training Accuracy: 0.7550, Validation Accuracy: 0.6798
# Epoch 70, Training Loss: 0.5117, Validation Loss: 0.5886, Training Accuracy: 0.7619, Validation Accuracy: 0.6759
# Epoch 71, Training Loss: 0.5112, Validation Loss: 0.5886, Training Accuracy: 0.7520, Validation Accuracy: 0.6877
# Epoch 72, Training Loss: 0.5103, Validation Loss: 0.5874, Training Accuracy: 0.7560, Validation Accuracy: 0.6798
# Epoch 73, Training Loss: 0.5099, Validation Loss: 0.5881, Training Accuracy: 0.7560, Validation Accuracy: 0.6917
# Epoch 74, Training Loss: 0.5067, Validation Loss: 0.5861, Training Accuracy: 0.7569, Validation Accuracy: 0.6838
# Epoch 75, Training Loss: 0.5071, Validation Loss: 0.5907, Training Accuracy: 0.7550, Validation Accuracy: 0.6877
# Epoch 76, Training Loss: 0.5070, Validation Loss: 0.5872, Training Accuracy: 0.7609, Validation Accuracy: 0.6957
# Epoch 77, Training Loss: 0.5063, Validation Loss: 0.5870, Training Accuracy: 0.7550, Validation Accuracy: 0.6838
# Epoch 78, Training Loss: 0.5044, Validation Loss: 0.5892, Training Accuracy: 0.7609, Validation Accuracy: 0.6877
# Epoch 79, Training Loss: 0.5024, Validation Loss: 0.5899, Training Accuracy: 0.7609, Validation Accuracy: 0.6798
# Epoch 80, Training Loss: 0.5014, Validation Loss: 0.5878, Training Accuracy: 0.7609, Validation Accuracy: 0.6798
# Epoch 81, Training Loss: 0.5025, Validation Loss: 0.5890, Training Accuracy: 0.7589, Validation Accuracy: 0.6838
# Epoch 82, Training Loss: 0.5006, Validation Loss: 0.5880, Training Accuracy: 0.7639, Validation Accuracy: 0.6877
# Epoch 83, Training Loss: 0.5004, Validation Loss: 0.5878, Training Accuracy: 0.7599, Validation Accuracy: 0.6798
# Epoch 84, Training Loss: 0.5012, Validation Loss: 0.5879, Training Accuracy: 0.7629, Validation Accuracy: 0.6838
# Epoch 85, Training Loss: 0.4992, Validation Loss: 0.5904, Training Accuracy: 0.7649, Validation Accuracy: 0.6877
# Epoch 86, Training Loss: 0.4973, Validation Loss: 0.5905, Training Accuracy: 0.7649, Validation Accuracy: 0.6877
# Epoch 87, Training Loss: 0.4969, Validation Loss: 0.5900, Training Accuracy: 0.7688, Validation Accuracy: 0.6877
# Epoch 88, Training Loss: 0.4957, Validation Loss: 0.5910, Training Accuracy: 0.7669, Validation Accuracy: 0.6877
# Epoch 89, Training Loss: 0.4954, Validation Loss: 0.5902, Training Accuracy: 0.7708, Validation Accuracy: 0.6838
# Epoch 90, Training Loss: 0.4927, Validation Loss: 0.5885, Training Accuracy: 0.7748, Validation Accuracy: 0.6719
# Epoch 91, Training Loss: 0.4944, Validation Loss: 0.5894, Training Accuracy: 0.7768, Validation Accuracy: 0.6838
# Epoch 92, Training Loss: 0.4930, Validation Loss: 0.5902, Training Accuracy: 0.7669, Validation Accuracy: 0.6877
# Epoch 93, Training Loss: 0.4921, Validation Loss: 0.5924, Training Accuracy: 0.7708, Validation Accuracy: 0.6640
# Epoch 94, Training Loss: 0.4902, Validation Loss: 0.5899, Training Accuracy: 0.7708, Validation Accuracy: 0.6759
# Epoch 95, Training Loss: 0.4894, Validation Loss: 0.5899, Training Accuracy: 0.7708, Validation Accuracy: 0.6640
# Epoch 96, Training Loss: 0.4885, Validation Loss: 0.5910, Training Accuracy: 0.7768, Validation Accuracy: 0.6759
# Epoch 97, Training Loss: 0.4886, Validation Loss: 0.5937, Training Accuracy: 0.7738, Validation Accuracy: 0.6759
# Epoch 98, Training Loss: 0.4863, Validation Loss: 0.5894, Training Accuracy: 0.7798, Validation Accuracy: 0.6680
# Epoch 99, Training Loss: 0.4858, Validation Loss: 0.5939, Training Accuracy: 0.7748, Validation Accuracy: 0.6759
# Epoch 100, Training Loss: 0.4838, Validation Loss: 0.5908, Training Accuracy: 0.7847, Validation Accuracy: 0.6798
# Epoch 101, Training Loss: 0.4865, Validation Loss: 0.5949, Training Accuracy: 0.7738, Validation Accuracy: 0.6798
# Epoch 102, Training Loss: 0.4851, Validation Loss: 0.5912, Training Accuracy: 0.7817, Validation Accuracy: 0.6798
# Epoch 103, Training Loss: 0.4828, Validation Loss: 0.5918, Training Accuracy: 0.7768, Validation Accuracy: 0.6719
# Epoch 104, Training Loss: 0.4825, Validation Loss: 0.5902, Training Accuracy: 0.7827, Validation Accuracy: 0.6759
# Epoch 105, Training Loss: 0.4817, Validation Loss: 0.5918, Training Accuracy: 0.7847, Validation Accuracy: 0.6759
# Epoch 106, Training Loss: 0.4812, Validation Loss: 0.5918, Training Accuracy: 0.7758, Validation Accuracy: 0.6759
# Epoch 107, Training Loss: 0.4795, Validation Loss: 0.5909, Training Accuracy: 0.7827, Validation Accuracy: 0.6759
# Epoch 108, Training Loss: 0.4796, Validation Loss: 0.5973, Training Accuracy: 0.7857, Validation Accuracy: 0.6719
# Epoch 109, Training Loss: 0.4791, Validation Loss: 0.5931, Training Accuracy: 0.7837, Validation Accuracy: 0.6640
# Epoch 110, Training Loss: 0.4754, Validation Loss: 0.5916, Training Accuracy: 0.7788, Validation Accuracy: 0.6798
# Epoch 111, Training Loss: 0.4759, Validation Loss: 0.5947, Training Accuracy: 0.7798, Validation Accuracy: 0.6680
# Epoch 112, Training Loss: 0.4753, Validation Loss: 0.5931, Training Accuracy: 0.7867, Validation Accuracy: 0.6719
# Epoch 113, Training Loss: 0.4742, Validation Loss: 0.5926, Training Accuracy: 0.7887, Validation Accuracy: 0.6719
# Epoch 114, Training Loss: 0.4742, Validation Loss: 0.5979, Training Accuracy: 0.7877, Validation Accuracy: 0.6719
# Epoch 115, Training Loss: 0.4723, Validation Loss: 0.5950, Training Accuracy: 0.7907, Validation Accuracy: 0.6759
# Epoch 116, Training Loss: 0.4721, Validation Loss: 0.5957, Training Accuracy: 0.7847, Validation Accuracy: 0.6680
# Epoch 117, Training Loss: 0.4698, Validation Loss: 0.5968, Training Accuracy: 0.7827, Validation Accuracy: 0.6798
# Epoch 118, Training Loss: 0.4712, Validation Loss: 0.5940, Training Accuracy: 0.7897, Validation Accuracy: 0.6759
# Epoch 119, Training Loss: 0.4674, Validation Loss: 0.5974, Training Accuracy: 0.7837, Validation Accuracy: 0.6759
# Epoch 120, Training Loss: 0.4687, Validation Loss: 0.5973, Training Accuracy: 0.7867, Validation Accuracy: 0.6719
# Epoch 121, Training Loss: 0.4680, Validation Loss: 0.5956, Training Accuracy: 0.7917, Validation Accuracy: 0.6798
# Epoch 122, Training Loss: 0.4658, Validation Loss: 0.5965, Training Accuracy: 0.7847, Validation Accuracy: 0.6798
# Epoch 123, Training Loss: 0.4639, Validation Loss: 0.5996, Training Accuracy: 0.7907, Validation Accuracy: 0.6759
# Epoch 124, Training Loss: 0.4664, Validation Loss: 0.5998, Training Accuracy: 0.7887, Validation Accuracy: 0.6759
# Epoch 125, Training Loss: 0.4655, Validation Loss: 0.5989, Training Accuracy: 0.7907, Validation Accuracy: 0.6680
# Epoch 126, Training Loss: 0.4654, Validation Loss: 0.5989, Training Accuracy: 0.7847, Validation Accuracy: 0.6719
# Epoch 127, Training Loss: 0.4628, Validation Loss: 0.5980, Training Accuracy: 0.7966, Validation Accuracy: 0.6719
# Epoch 128, Training Loss: 0.4624, Validation Loss: 0.5991, Training Accuracy: 0.7956, Validation Accuracy: 0.6719
# Epoch 129, Training Loss: 0.4630, Validation Loss: 0.5991, Training Accuracy: 0.7937, Validation Accuracy: 0.6719
# Epoch 130, Training Loss: 0.4600, Validation Loss: 0.6006, Training Accuracy: 0.7946, Validation Accuracy: 0.6719
# Epoch 131, Training Loss: 0.4582, Validation Loss: 0.6002, Training Accuracy: 0.7996, Validation Accuracy: 0.6719
# Epoch 132, Training Loss: 0.4595, Validation Loss: 0.6019, Training Accuracy: 0.7996, Validation Accuracy: 0.6680
# Epoch 133, Training Loss: 0.4564, Validation Loss: 0.6047, Training Accuracy: 0.8006, Validation Accuracy: 0.6680
# Epoch 134, Training Loss: 0.4581, Validation Loss: 0.5978, Training Accuracy: 0.7956, Validation Accuracy: 0.6601
# Epoch 135, Training Loss: 0.4563, Validation Loss: 0.6005, Training Accuracy: 0.7937, Validation Accuracy: 0.6640
# Epoch 136, Training Loss: 0.4545, Validation Loss: 0.6017, Training Accuracy: 0.7976, Validation Accuracy: 0.6719
# Epoch 137, Training Loss: 0.4557, Validation Loss: 0.6025, Training Accuracy: 0.7927, Validation Accuracy: 0.6680
# Epoch 138, Training Loss: 0.4543, Validation Loss: 0.6047, Training Accuracy: 0.7966, Validation Accuracy: 0.6680
# Epoch 139, Training Loss: 0.4521, Validation Loss: 0.6008, Training Accuracy: 0.8036, Validation Accuracy: 0.6759
# Epoch 140, Training Loss: 0.4514, Validation Loss: 0.6059, Training Accuracy: 0.8026, Validation Accuracy: 0.6719
# Epoch 141, Training Loss: 0.4486, Validation Loss: 0.6026, Training Accuracy: 0.8026, Validation Accuracy: 0.6719
# Epoch 142, Training Loss: 0.4495, Validation Loss: 0.6048, Training Accuracy: 0.7907, Validation Accuracy: 0.6719
# Epoch 143, Training Loss: 0.4465, Validation Loss: 0.6037, Training Accuracy: 0.8095, Validation Accuracy: 0.6719
# Epoch 144, Training Loss: 0.4483, Validation Loss: 0.6064, Training Accuracy: 0.7986, Validation Accuracy: 0.6759
# Epoch 145, Training Loss: 0.4478, Validation Loss: 0.6061, Training Accuracy: 0.8006, Validation Accuracy: 0.6719
# Epoch 146, Training Loss: 0.4481, Validation Loss: 0.6056, Training Accuracy: 0.8006, Validation Accuracy: 0.6719
# Epoch 147, Training Loss: 0.4477, Validation Loss: 0.6070, Training Accuracy: 0.8056, Validation Accuracy: 0.6680
# Epoch 148, Training Loss: 0.4467, Validation Loss: 0.6067, Training Accuracy: 0.8036, Validation Accuracy: 0.6719
# Epoch 149, Training Loss: 0.4457, Validation Loss: 0.6078, Training Accuracy: 0.8046, Validation Accuracy: 0.6759
# Epoch 150, Training Loss: 0.4427, Validation Loss: 0.6085, Training Accuracy: 0.8036, Validation Accuracy: 0.6680
# Epoch 151, Training Loss: 0.4431, Validation Loss: 0.6097, Training Accuracy: 0.8095, Validation Accuracy: 0.6601
# Epoch 152, Training Loss: 0.4415, Validation Loss: 0.6066, Training Accuracy: 0.8065, Validation Accuracy: 0.6759
# Epoch 153, Training Loss: 0.4407, Validation Loss: 0.6080, Training Accuracy: 0.8125, Validation Accuracy: 0.6680
# Epoch 154, Training Loss: 0.4426, Validation Loss: 0.6128, Training Accuracy: 0.8065, Validation Accuracy: 0.6719
# Epoch 155, Training Loss: 0.4420, Validation Loss: 0.6100, Training Accuracy: 0.8006, Validation Accuracy: 0.6719
# Epoch 156, Training Loss: 0.4390, Validation Loss: 0.6104, Training Accuracy: 0.8065, Validation Accuracy: 0.6719
# Epoch 157, Training Loss: 0.4377, Validation Loss: 0.6087, Training Accuracy: 0.8065, Validation Accuracy: 0.6719
# Epoch 158, Training Loss: 0.4401, Validation Loss: 0.6080, Training Accuracy: 0.8056, Validation Accuracy: 0.6680
# Epoch 159, Training Loss: 0.4357, Validation Loss: 0.6094, Training Accuracy: 0.8095, Validation Accuracy: 0.6759
# Epoch 160, Training Loss: 0.4361, Validation Loss: 0.6095, Training Accuracy: 0.8065, Validation Accuracy: 0.6640
# Epoch 161, Training Loss: 0.4360, Validation Loss: 0.6080, Training Accuracy: 0.8075, Validation Accuracy: 0.6719
# Epoch 162, Training Loss: 0.4346, Validation Loss: 0.6103, Training Accuracy: 0.8036, Validation Accuracy: 0.6640
# Epoch 163, Training Loss: 0.4334, Validation Loss: 0.6109, Training Accuracy: 0.8085, Validation Accuracy: 0.6640
# Epoch 164, Training Loss: 0.4319, Validation Loss: 0.6147, Training Accuracy: 0.8125, Validation Accuracy: 0.6680
# Epoch 165, Training Loss: 0.4335, Validation Loss: 0.6136, Training Accuracy: 0.8135, Validation Accuracy: 0.6759
# Epoch 166, Training Loss: 0.4325, Validation Loss: 0.6150, Training Accuracy: 0.8165, Validation Accuracy: 0.6640
# Epoch 167, Training Loss: 0.4305, Validation Loss: 0.6122, Training Accuracy: 0.8125, Validation Accuracy: 0.6601
# Epoch 168, Training Loss: 0.4305, Validation Loss: 0.6123, Training Accuracy: 0.8085, Validation Accuracy: 0.6680
# Epoch 169, Training Loss: 0.4290, Validation Loss: 0.6132, Training Accuracy: 0.8115, Validation Accuracy: 0.6640
# Epoch 170, Training Loss: 0.4269, Validation Loss: 0.6155, Training Accuracy: 0.8125, Validation Accuracy: 0.6680
# Epoch 171, Training Loss: 0.4282, Validation Loss: 0.6175, Training Accuracy: 0.8175, Validation Accuracy: 0.6759
# Epoch 172, Training Loss: 0.4258, Validation Loss: 0.6173, Training Accuracy: 0.8145, Validation Accuracy: 0.6680
# Epoch 173, Training Loss: 0.4270, Validation Loss: 0.6165, Training Accuracy: 0.8145, Validation Accuracy: 0.6719
# Epoch 174, Training Loss: 0.4254, Validation Loss: 0.6183, Training Accuracy: 0.8065, Validation Accuracy: 0.6680
# Epoch 175, Training Loss: 0.4237, Validation Loss: 0.6164, Training Accuracy: 0.8194, Validation Accuracy: 0.6719
# Epoch 176, Training Loss: 0.4253, Validation Loss: 0.6192, Training Accuracy: 0.8085, Validation Accuracy: 0.6680
# Epoch 177, Training Loss: 0.4236, Validation Loss: 0.6186, Training Accuracy: 0.8165, Validation Accuracy: 0.6680
# Epoch 178, Training Loss: 0.4230, Validation Loss: 0.6194, Training Accuracy: 0.8145, Validation Accuracy: 0.6719
# Epoch 179, Training Loss: 0.4216, Validation Loss: 0.6195, Training Accuracy: 0.8125, Validation Accuracy: 0.6680
# Epoch 180, Training Loss: 0.4196, Validation Loss: 0.6187, Training Accuracy: 0.8244, Validation Accuracy: 0.6680
# Epoch 181, Training Loss: 0.4200, Validation Loss: 0.6233, Training Accuracy: 0.8105, Validation Accuracy: 0.6640
# Epoch 182, Training Loss: 0.4210, Validation Loss: 0.6226, Training Accuracy: 0.8165, Validation Accuracy: 0.6719
# Epoch 183, Training Loss: 0.4190, Validation Loss: 0.6227, Training Accuracy: 0.8155, Validation Accuracy: 0.6640
# Epoch 184, Training Loss: 0.4195, Validation Loss: 0.6227, Training Accuracy: 0.8175, Validation Accuracy: 0.6640
# Epoch 185, Training Loss: 0.4174, Validation Loss: 0.6258, Training Accuracy: 0.8155, Validation Accuracy: 0.6680
# Epoch 186, Training Loss: 0.4155, Validation Loss: 0.6224, Training Accuracy: 0.8194, Validation Accuracy: 0.6601
# Epoch 187, Training Loss: 0.4154, Validation Loss: 0.6236, Training Accuracy: 0.8224, Validation Accuracy: 0.6640
# Epoch 188, Training Loss: 0.4151, Validation Loss: 0.6262, Training Accuracy: 0.8214, Validation Accuracy: 0.6640
# Epoch 189, Training Loss: 0.4140, Validation Loss: 0.6266, Training Accuracy: 0.8175, Validation Accuracy: 0.6680
# Epoch 190, Training Loss: 0.4140, Validation Loss: 0.6252, Training Accuracy: 0.8175, Validation Accuracy: 0.6601
# Epoch 191, Training Loss: 0.4121, Validation Loss: 0.6239, Training Accuracy: 0.8224, Validation Accuracy: 0.6561
# Epoch 192, Training Loss: 0.4134, Validation Loss: 0.6245, Training Accuracy: 0.8194, Validation Accuracy: 0.6640
# Epoch 193, Training Loss: 0.4132, Validation Loss: 0.6269, Training Accuracy: 0.8254, Validation Accuracy: 0.6640
# Epoch 194, Training Loss: 0.4123, Validation Loss: 0.6308, Training Accuracy: 0.8194, Validation Accuracy: 0.6680
# Epoch 195, Training Loss: 0.4114, Validation Loss: 0.6288, Training Accuracy: 0.8115, Validation Accuracy: 0.6601
# Epoch 196, Training Loss: 0.4083, Validation Loss: 0.6313, Training Accuracy: 0.8204, Validation Accuracy: 0.6640
# Epoch 197, Training Loss: 0.4093, Validation Loss: 0.6290, Training Accuracy: 0.8244, Validation Accuracy: 0.6719
# Epoch 198, Training Loss: 0.4067, Validation Loss: 0.6284, Training Accuracy: 0.8204, Validation Accuracy: 0.6601
# Epoch 199, Training Loss: 0.4067, Validation Loss: 0.6314, Training Accuracy: 0.8214, Validation Accuracy: 0.6640
# Epoch 200, Training Loss: 0.4085, Validation Loss: 0.6302, Training Accuracy: 0.8224, Validation Accuracy: 0.6640
# Métricas de Evaluación:
#               precision    recall  f1-score   support
#
#     Negative       0.72      0.64      0.68       140
#     Positive       0.61      0.70      0.65       113
#
#     accuracy                           0.66       253
#    macro avg       0.67      0.67      0.66       253
# weighted avg       0.67      0.66      0.66       253
#
# Especificidad: 0.6357
# Estadístico Kappa: 0.3300

# %% [markdown]
# ### Pérdida de Entrenamiento y Validación
# En esta gráfica, observamos que la **pérdida de entrenamiento** (línea azul) disminuye constantemente a lo largo de las épocas, lo que indica que el modelo está aprendiendo y ajustándose mejor a los datos de entrenamiento. Sin embargo, la **pérdida de validación** (línea naranja) muestra un comportamiento diferente. Aunque inicialmente disminuye, lo que es positivo, después comienza a aumentar gradualmente. Este incremento sugiere que el modelo está empezando a sobreajustarse a los datos de entrenamiento, lo cual significa que, aunque mejora en estos datos, su capacidad para generalizar a nuevos datos está disminuyendo.

# %% [markdown]
# ### Precisión de Entrenamiento y Validación
# La **precisión de entrenamiento** (línea azul) aumenta consistentemente, indicando que el modelo está aprendiendo a clasificar correctamente las secuencias de entrenamiento con el tiempo. Sin embargo, la **precisión de validación** (línea naranja) se estabiliza y fluctúa considerablemente después de las primeras épocas, lo que sugiere problemas de sobreajuste y una capacidad limitada del modelo para generalizar a los datos de validación.

# %% [markdown]
# ### Mejoras Potenciales para el Modelo
#
# Para mejorar el rendimiento del modelo, se pueden considerar varias estrategias: incrementar tasa de dropout para reducir el sobreajuste; ajustar hiperparámetros como la tasa de aprendizaje, el tamaño del lote, y el número de capas y neuronas en el modelo; utilizar un conjunto de datos más grande y diverso para mejorar la capacidad de generalización; aplicar técnicas de data augmentation para generar nuevas muestras sintéticas; o implementar validación cruzada para una evaluación más robusta del modelo. Estas mejoras pueden mitigar el sobreajuste y aumentar la capacidad del modelo para generalizar a nuevos datos.
