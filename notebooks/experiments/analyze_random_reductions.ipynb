# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.random_projection import SparseRandomProjection

from project_root.dataset.dataset_loader import DatasetLoader
from project_root.dataset.protein_dataset import ProteinDataset
from project_root.utils.feature_processor import (
    flatten_attention_weights,
    pad_attention_weights,
    apply_random_projection_globaly,
    apply_random_projection_by_prot,
)

# Define data path
path_dataset_folder = "../DATASETS/"

print(">>> Analyzing representation of attention weights...")

# Load data
loader = DatasetLoader(path_dataset_folder)
df = loader.load_dataframe()
embeddings, attention_weights = loader.load_embeddings_and_attention()

print(f"Data loaded → df: {df.shape}, embeddings: {len(embeddings)}, attention_weights: {len(attention_weights)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 from sklearn.random_projection import SparseRandomProjection
#      10 from project_root.dataset.dataset_loader import DatasetLoader
# ---> 11 from project_root.dataset.protein_dataset import ProteinDataset
#      12 from project_root.utils.feature_processor import (
#      13     flatten_attention_weights,
#      14     pad_attention_weights,
#      15     apply_random_projection_globaly,
#      16     apply_random_projection_by_prot,
#      17 )
#      19 # Define data path
#
# File ~/Computational-Analysis-of-Moonlighting-Proteins/project_root/dataset/protein_dataset.py:2
#       1 import os
# ----> 2 import torch
#       3 import pandas as pd
#       4 from torch.utils.data import Dataset
#
# File ~/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/torch/__init__.py:77
#      74 else:
#      75     from typing_extensions import TypeIs as _TypeIs
# ---> 77     from torch.torch_version import __version__ as __version__
#      79 __all__ = [
#      80     "BoolStorage",
#      81     "BoolTensor",
#    (...)
#     150     "vmap",
#     151 ]
#     153 # Please keep this list sorted
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:846, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:941, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1040, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
attention_weights_by_prot = {}

for att in attention_weights:
    print(f"Attention weights: {att}")
    print(f"Shape: {attention_weights[att].shape}")

    proj = SparseRandomProjection(n_components=400, random_state=42)
    attention_weights_by_prot[att] = proj.fit_transform(attention_weights[att])
# Out:
# Attention weights: Q9Y2X8
# Shape: (877, 877)
# Attention weights: Q05086
# Shape: (877, 877)
# Attention weights: Q9Y6X0
# Shape: (1598, 1598)
# Attention weights: Q8BH75
# Shape: (723, 723)
# Attention weights: Q04120
# Shape: (723, 723)
# Attention weights: P61077
# Shape: (723, 723)
# Attention weights: Q16659
# Shape: (723, 723)
# Attention weights: Q6UWE0
# Shape: (918, 918)
# Attention weights: Q8IWX8
# Shape: (918, 918)
# Attention weights: P43364
# Shape: (431, 431)
# Attention weights: Q969T4
# Shape: (431, 431)
# Attention weights: P06151
# Shape: (431, 431)
# Attention weights: Q96LR5
# Shape: (431, 431)
# Attention weights: P23568
# Shape: (396, 396)
# Attention weights: Q06449
# Shape: (396, 396)
# Attention weights: P54786
# Shape: (944, 944)
# Attention weights: Q9VU87
# Shape: (944, 944)
# Attention weights: Q9Y2D8
# Shape: (1077, 1077)
# Attention weights: Q9VDV4
# Shape: (1077, 1077)
# Attention weights: P48601
# Shape: (696, 696)
# Attention weights: P50142
# Shape: (696, 696)
# Attention weights: Q13480
# Shape: (696, 696)
# Attention weights: P40054
# Shape: (696, 696)
# Attention weights: Q15477
# Shape: (1248, 1248)
# Attention weights: Q92734
# Shape: (548, 548)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (396 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (396 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: Q9H211
# Shape: (548, 548)
# Attention weights: P31230
# Shape: (548, 548)
# Attention weights: P43593
# Shape: (548, 548)
# Attention weights: P49710
# Shape: (548, 548)
# Attention weights: P34960
# Shape: (548, 548)
# Attention weights: Q9V4S8
# Shape: (548, 548)
# Attention weights: P32835
# Shape: (548, 548)
# Attention weights: Q9GZM8
# Shape: (760, 760)
# Attention weights: Q92890
# Shape: (760, 760)
# Attention weights: P16143
# Shape: (760, 760)
# Attention weights: P28862
# Shape: (760, 760)
# Attention weights: P0AG40
# Shape: (315, 315)
# Attention weights: Q9C0C9
# Shape: (1294, 1294)
# Attention weights: Q9NPI8
# Shape: (467, 467)
# Attention weights: Q9C019
# Shape: (467, 467)
# Attention weights: Q15843
# Shape: (83, 83)
# Attention weights: P32189
# Shape: (561, 561)
# Attention weights: Q86VP1
# Shape: (857, 857)
# Attention weights: Q7YZX3
# Shape: (857, 857)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (315 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (83 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: Q9KKF0
# Shape: (857, 857)
# Attention weights: Q8N0Z3
# Shape: (857, 857)
# Attention weights: P51668
# Shape: (857, 857)
# Attention weights: P31681
# Shape: (857, 857)
# Attention weights: Q16543
# Shape: (857, 857)
# Attention weights: P02489
# Shape: (857, 857)
# Attention weights: P69786
# Shape: (718, 718)
# Attention weights: P46273
# Shape: (718, 718)
# Attention weights: Q96LK0
# Shape: (718, 718)
# Attention weights: P82612
# Shape: (718, 718)
# Attention weights: P75391
# Shape: (718, 718)
# Attention weights: P07335
# Shape: (718, 718)
# Attention weights: Q92997
# Shape: (718, 718)
# Attention weights: Q9UHD9
# Shape: (718, 718)
# Attention weights: P0CG48
# Shape: (870, 870)
# Attention weights: P02511
# Shape: (870, 870)
# Attention weights: P04792
# Shape: (870, 870)
# Attention weights: Q8WUM4
# Shape: (870, 870)
# Attention weights: P50362
# Shape: (1245, 1245)
# Attention weights: Q21921
# Shape: (1245, 1245)
# Attention weights: Q3UVR3
# Shape: (1245, 1245)
# Attention weights: P03957
# Shape: (1245, 1245)
# Attention weights: P46587
# Shape: (898, 898)
# Attention weights: Q05128
# Shape: (898, 898)
# Attention weights: P41797
# Shape: (898, 898)
# Attention weights: P11574
# Shape: (898, 898)
# Attention weights: Q9CZD3
# Shape: (898, 898)
# Attention weights: P42566
# Shape: (898, 898)
# Attention weights: Q9SSE7
# Shape: (898, 898)
# Attention weights: P43274
# Shape: (898, 898)
# Attention weights: Q9URB4
# Shape: (819, 819)
# Attention weights: Q383B2
# Shape: (819, 819)
# Attention weights: P39743
# Shape: (819, 819)
# Attention weights: P38822
# Shape: (819, 819)
# Attention weights: P37370
# Shape: (819, 819)
# Attention weights: P06367
# Shape: (819, 819)
# Attention weights: P32856
# Shape: (819, 819)
# Attention weights: Q9QWV4
# Shape: (819, 819)
# Attention weights: P47135
# Shape: (1142, 1142)
# Attention weights: Q74JU6
# Shape: (1142, 1142)
# Attention weights: P62837
# Shape: (1142, 1142)
# Attention weights: Q66GS9
# Shape: (1142, 1142)
# Attention weights: P47992
# Shape: (314, 314)
# Attention weights: P05230
# Shape: (314, 314)
# Attention weights: Q12904
# Shape: (314, 314)
# Attention weights: P0A7W7
# Shape: (314, 314)
# Attention weights: P0A7L0
# Shape: (601, 601)
# Attention weights: P23219
# Shape: (601, 601)
# Attention weights: Q93VT9
# Shape: (222, 222)
# Attention weights: P48415
# Shape: (2197, 2197)
# Attention weights: Q75NZ0
# Shape: (687, 687)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (314 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (314 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (314 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (314 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (222 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: Q14103
# Shape: (687, 687)
# Attention weights: P59240
# Shape: (1427, 1427)
# Attention weights: O75674
# Shape: (1427, 1427)
# Attention weights: P25858
# Shape: (554, 554)
# Attention weights: P11415
# Shape: (554, 554)
# Attention weights: Q9K498
# Shape: (554, 554)
# Attention weights: Q9Z0E3
# Shape: (554, 554)
# Attention weights: P0ADY3
# Shape: (554, 554)
# Attention weights: Q61171
# Shape: (554, 554)
# Attention weights: Q9H8X2
# Shape: (554, 554)
# Attention weights: P25233
# Shape: (554, 554)
# Attention weights: P0A7R5
# Shape: (167, 167)
# Attention weights: P0A7J3
# Shape: (167, 167)
# Attention weights: P02359
# Shape: (1384, 1384)
# Attention weights: Q14152
# Shape: (1384, 1384)
# Attention weights: Q04439
# Shape: (1246, 1246)
# Attention weights: Q08117
# Shape: (1246, 1246)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (167 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (167 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P32790
# Shape: (1246, 1246)
# Attention weights: P24058
# Shape: (1246, 1246)
# Attention weights: P63104
# Shape: (932, 932)
# Attention weights: P98175
# Shape: (932, 932)
# Attention weights: Q9BQB6
# Shape: (932, 932)
# Attention weights: Q15637
# Shape: (932, 932)
# Attention weights: Q03790
# Shape: (477, 477)
# Attention weights: Q13404
# Shape: (477, 477)
# Attention weights: Q14160
# Shape: (1632, 1632)
# Attention weights: O75330
# Shape: (1632, 1632)
# Attention weights: Q3E7X9
# Shape: (831, 831)
# Attention weights: Q9NRD5
# Shape: (831, 831)
# Attention weights: P04807
# Shape: (831, 831)
# Attention weights: P0CX45
# Shape: (831, 831)
# Attention weights: Q15038
# Shape: (831, 831)
# Attention weights: Q96AP0
# Shape: (831, 831)
# Attention weights: Q5BJF6
# Shape: (831, 831)
# Attention weights: Q6NUS6
# Shape: (831, 831)
# Attention weights: Q9NYB9
# Shape: (515, 515)
# Attention weights: Q3HL75
# Shape: (515, 515)
# Attention weights: Q9CR42
# Shape: (1623, 1623)
# Attention weights: Q43155
# Shape: (1623, 1623)
# Attention weights: P05979
# Shape: (1312, 1312)
# Attention weights: Q9BYE9
# Shape: (1312, 1312)
# Attention weights: P0C0V0
# Shape: (1457, 1457)
# Attention weights: O15360
# Shape: (1457, 1457)
# Attention weights: P41834
# Shape: (865, 865)
# Attention weights: Q01217
# Shape: (865, 865)
# Attention weights: Q96VN5
# Shape: (865, 865)
# Attention weights: P54253
# Shape: (865, 865)
# Attention weights: P07359
# Shape: (1219, 1219)
# Attention weights: O15287
# Shape: (1219, 1219)
# Attention weights: Q9UQE7
# Shape: (1219, 1219)
# Attention weights: Q06208
# Shape: (1219, 1219)
# Attention weights: P29055
# Shape: (411, 411)
# Attention weights: Q9Y7F0
# Shape: (411, 411)
# Attention weights: Q94420
# Shape: (411, 411)
# Attention weights: P32121
# Shape: (411, 411)
# Attention weights: Q6ZU80
# Shape: (1096, 1096)
# Attention weights: Q9NRI5
# Shape: (1096, 1096)
# Attention weights: Q7L5D6
# Shape: (1096, 1096)
# Attention weights: Q14247
# Shape: (1096, 1096)
# Attention weights: P00805
# Shape: (1219, 1219)
# Attention weights: Q9BWF3
# Shape: (1219, 1219)
# Attention weights: O15151
# Shape: (1219, 1219)
# Attention weights: Q9CW03
# Shape: (1219, 1219)
# Attention weights: P56192
# Shape: (902, 902)
# Attention weights: P39099
# Shape: (902, 902)
# Attention weights: P23202
# Shape: (902, 902)
# Attention weights: P14540
# Shape: (902, 902)
# Attention weights: Q12309
# Shape: (902, 902)
# Attention weights: Q08438
# Shape: (902, 902)
# Attention weights: Q8R010
# Shape: (902, 902)
# Attention weights: P0A7V8
# Shape: (902, 902)
# Attention weights: Q9D1M4
# Shape: (738, 738)
# Attention weights: P14120
# Shape: (738, 738)
# Attention weights: P19338
# Shape: (738, 738)
# Attention weights: Q9NQX3
# Shape: (738, 738)
# Attention weights: Q5JFD7
# Shape: (738, 738)
# Attention weights: P9WQN9
# Shape: (738, 738)
# Attention weights: P9WQP1
# Shape: (738, 738)
# Attention weights: P9WQP3
# Shape: (738, 738)
# Attention weights: P32527
# Shape: (435, 435)
# Attention weights: Q5JFG7
# Shape: (435, 435)
# Attention weights: P36969
# Shape: (435, 435)
# Attention weights: P76014
# Shape: (435, 435)
# Attention weights: O35244
# Shape: (435, 435)
# Attention weights: P05062
# Shape: (435, 435)
# Attention weights: P48962
# Shape: (435, 435)
# Attention weights: P51881
# Shape: (435, 435)
# Attention weights: P61978
# Shape: (465, 465)
# Attention weights: P12235
# Shape: (465, 465)
# Attention weights: P23256
# Shape: (465, 465)
# Attention weights: P46108
# Shape: (465, 465)
# Attention weights: Q80VW7
# Shape: (1406, 1406)
# Attention weights: P19971
# Shape: (1406, 1406)
# Attention weights: P51965
# Shape: (737, 737)
# Attention weights: P05064
# Shape: (737, 737)
# Attention weights: Q15750
# Shape: (737, 737)
# Attention weights: P04764
# Shape: (737, 737)
# Attention weights: P45973
# Shape: (737, 737)
# Attention weights: P09382
# Shape: (737, 737)
# Attention weights: Q8DTS9
# Shape: (737, 737)
# Attention weights: Q9UJV3
# Shape: (737, 737)
# Attention weights: P36024
# Shape: (1274, 1274)
# Attention weights: P28741
# Shape: (1274, 1274)
# Attention weights: P30575
# Shape: (1274, 1274)
# Attention weights: Q9HAU5
# Shape: (1274, 1274)
# Attention weights: Q9Y3E5
# Shape: (650, 650)
# Attention weights: P0AFW0
# Shape: (650, 650)
# Attention weights: P07017
# Shape: (650, 650)
# Attention weights: Q9NR28
# Shape: (650, 650)
# Attention weights: Q9NPD3
# Shape: (650, 650)
# Attention weights: P04049
# Shape: (650, 650)
# Attention weights: Q07637
# Shape: (650, 650)
# Attention weights: A0A1D8PFS4
# Shape: (650, 650)
# Attention weights: Q9H190
# Shape: (364, 364)
# Attention weights: P99999
# Shape: (364, 364)
# Attention weights: P21266
# Shape: (364, 364)
# Attention weights: Q9H0A6
# Shape: (364, 364)
# Attention weights: P76015
# Shape: (364, 364)
# Attention weights: P16858
# Shape: (364, 364)
# Attention weights: P00330
# Shape: (364, 364)
# Attention weights: A5D8V6
# Shape: (364, 364)
# Attention weights: Q6Q3I2
# Shape: (868, 868)
# Attention weights: P07250
# Shape: (868, 868)
# Attention weights: P00558
# Shape: (868, 868)
# Attention weights: P00360
# Shape: (868, 868)
# Attention weights: Q95VF2
# Shape: (868, 868)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (364 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P42834
# Shape: (868, 868)
# Attention weights: P0CT31
# Shape: (868, 868)
# Attention weights: Q12018
# Shape: (868, 868)
# Attention weights: P12425
# Shape: (505, 505)
# Attention weights: P31658
# Shape: (505, 505)
# Attention weights: P0CG47
# Shape: (505, 505)
# Attention weights: P68767
# Shape: (505, 505)
# Attention weights: Q42403
# Shape: (505, 505)
# Attention weights: P38011
# Shape: (505, 505)
# Attention weights: P50552
# Shape: (505, 505)
# Attention weights: P37887
# Shape: (505, 505)
# Attention weights: P30822
# Shape: (1086, 1086)
# Attention weights: Q24803
# Shape: (1086, 1086)
# Attention weights: P60520
# Shape: (1086, 1086)
# Attention weights: P25788
# Shape: (1086, 1086)
# Attention weights: P00924
# Shape: (826, 826)
# Attention weights: Q8N3Y7
# Shape: (826, 826)
# Attention weights: P27986
# Shape: (826, 826)
# Attention weights: P62258
# Shape: (826, 826)
# Attention weights: P08621
# Shape: (826, 826)
# Attention weights: P00925
# Shape: (826, 826)
# Attention weights: O00204
# Shape: (826, 826)
# Attention weights: Q13387
# Shape: (826, 826)
# Attention weights: P08670
# Shape: (987, 987)
# Attention weights: P80188
# Shape: (987, 987)
# Attention weights: P06744
# Shape: (987, 987)
# Attention weights: Q8TB24
# Shape: (987, 987)
# Attention weights: P53675
# Shape: (1642, 1642)
# Attention weights: P78352
# Shape: (1642, 1642)
# Attention weights: P47543
# Shape: (599, 599)
# Attention weights: P01583
# Shape: (599, 599)
# Attention weights: Q13501
# Shape: (599, 599)
# Attention weights: Q15046
# Shape: (599, 599)
# Attention weights: O95166
# Shape: (743, 743)
# Attention weights: P9WK17
# Shape: (743, 743)
# Attention weights: P23872
# Shape: (1325, 1325)
# Attention weights: Q96RG2
# Shape: (1325, 1325)
# Attention weights: Q8TBC4
# Shape: (465, 465)
# Attention weights: P60174
# Shape: (465, 465)
# Attention weights: P17931
# Shape: (465, 465)
# Attention weights: P09038
# Shape: (465, 465)
# Attention weights: P00445
# Shape: (156, 156)
# Attention weights: Q93062
# Shape: (772, 772)
# Attention weights: O04019
# Shape: (772, 772)
# Attention weights: Q9H307
# Shape: (772, 772)
# Attention weights: P04406
# Shape: (772, 772)
# Attention weights: P28241
# Shape: (772, 772)
# Attention weights: P55084
# Shape: (772, 772)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (156 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P42227
# Shape: (772, 772)
# Attention weights: Q12349
# Shape: (772, 772)
# Attention weights: P00359
# Shape: (770, 770)
# Attention weights: P00358
# Shape: (770, 770)
# Attention weights: P47017
# Shape: (770, 770)
# Attention weights: P15303
# Shape: (770, 770)
# Attention weights: P63159
# Shape: (937, 937)
# Attention weights: P19414
# Shape: (937, 937)
# Attention weights: P62328
# Shape: (937, 937)
# Attention weights: Q9VMB4
# Shape: (937, 937)
# Attention weights: P27487
# Shape: (768, 768)
# Attention weights: Q9MZB4
# Shape: (768, 768)
# Attention weights: P06168
# Shape: (768, 768)
# Attention weights: P00734
# Shape: (768, 768)
# Attention weights: Q05513
# Shape: (1039, 1039)
# Attention weights: P52735
# Shape: (1039, 1039)
# Attention weights: Q8WV44
# Shape: (1039, 1039)
# Attention weights: O00291
# Shape: (1039, 1039)
# Attention weights: P22736
# Shape: (1015, 1015)
# Attention weights: P11103
# Shape: (1015, 1015)
# Attention weights: Q8TAD8
# Shape: (1015, 1015)
# Attention weights: Q15428
# Shape: (1015, 1015)
# Attention weights: P63165
# Shape: (1004, 1004)
# Attention weights: Q24314
# Shape: (1004, 1004)
# Attention weights: P62829
# Shape: (1004, 1004)
# Attention weights: P62081
# Shape: (1004, 1004)
# Attention weights: O94906
# Shape: (943, 943)
# Attention weights: P9WPW9
# Shape: (943, 943)
# Attention weights: Q7LX99
# Shape: (943, 943)
# Attention weights: P11940
# Shape: (943, 943)
# Attention weights: P51948
# Shape: (311, 311)
# Attention weights: P63208
# Shape: (165, 165)
# Attention weights: P61254
# Shape: (872, 872)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (311 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (165 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: O00308
# Shape: (872, 872)
# Attention weights: P62310
# Shape: (872, 872)
# Attention weights: Q9BZR9
# Shape: (872, 872)
# Attention weights: P40429
# Shape: (872, 872)
# Attention weights: P10809
# Shape: (872, 872)
# Attention weights: Q13153
# Shape: (872, 872)
# Attention weights: P62277
# Shape: (872, 872)
# Attention weights: Q9BSI4
# Shape: (860, 860)
# Attention weights: P27635
# Shape: (860, 860)
# Attention weights: P0A7E9
# Shape: (860, 860)
# Attention weights: O00560
# Shape: (860, 860)
# Attention weights: Q8NEU8
# Shape: (860, 860)
# Attention weights: Q9C035
# Shape: (860, 860)
# Attention weights: P52286
# Shape: (860, 860)
# Attention weights: Q8IXK0
# Shape: (860, 860)
# Attention weights: Q05080
# Shape: (1411, 1411)
# Attention weights: Q63HR2
# Shape: (1411, 1411)
# Attention weights: O75604
# Shape: (1004, 1004)
# Attention weights: P46777
# Shape: (1004, 1004)
# Attention weights: Q08379
# Shape: (1004, 1004)
# Attention weights: O43464
# Shape: (1004, 1004)
# Attention weights: P27302
# Shape: (665, 665)
# Attention weights: P23381
# Shape: (665, 665)
# Attention weights: O00499
# Shape: (665, 665)
# Attention weights: P04797
# Shape: (665, 665)
# Attention weights: P62993
# Shape: (665, 665)
# Attention weights: P27361
# Shape: (665, 665)
# Attention weights: P62263
# Shape: (665, 665)
# Attention weights: Q13825
# Shape: (665, 665)
# Attention weights: Q27727
# Shape: (1178, 1178)
# Attention weights: P41250
# Shape: (1178, 1178)
# Attention weights: Q9P2J5
# Shape: (1178, 1178)
# Attention weights: P47897
# Shape: (1178, 1178)
# Attention weights: B9VJ59
# Shape: (584, 584)
# Attention weights: P63279
# Shape: (584, 584)
# Attention weights: P05141
# Shape: (1344, 1344)
# Attention weights: P21860
# Shape: (1344, 1344)
# Attention weights: Q9UMS4
# Shape: (1601, 1601)
# Attention weights: Q04637
# Shape: (1601, 1601)
# Attention weights: P62136
# Shape: (976, 976)
# Attention weights: P21399
# Shape: (976, 976)
# Attention weights: P33421
# Shape: (976, 976)
# Attention weights: P17710
# Shape: (976, 976)
# Attention weights: Q13200
# Shape: (910, 910)
# Attention weights: P49407
# Shape: (910, 910)
# Attention weights: P67809
# Shape: (910, 910)
# Attention weights: P28834
# Shape: (910, 910)
# Attention weights: P46937
# Shape: (913, 913)
# Attention weights: P02730
# Shape: (913, 913)
# Attention weights: P09429
# Shape: (913, 913)
# Attention weights: P34760
# Shape: (913, 913)
# Attention weights: P04075
# Shape: (826, 826)
# Attention weights: P27797
# Shape: (826, 826)
# Attention weights: P13716
# Shape: (826, 826)
# Attention weights: P43138
# Shape: (826, 826)
# Attention weights: P36873
# Shape: (826, 826)
# Attention weights: Q61371
# Shape: (826, 826)
# Attention weights: Q9UTI7
# Shape: (826, 826)
# Attention weights: P61088
# Shape: (826, 826)
# Attention weights: Q9NUX5
# Shape: (636, 636)
# Attention weights: P60723
# Shape: (636, 636)
# Attention weights: Q9UNE7
# Shape: (636, 636)
# Attention weights: P68400
# Shape: (636, 636)
# Attention weights: Q9UKG1
# Shape: (711, 711)
# Attention weights: Q8N8N0
# Shape: (711, 711)
# Attention weights: Q05201
# Shape: (768, 768)
# Attention weights: P14618
# Shape: (533, 533)
# Attention weights: P55072
# Shape: (808, 808)
# Attention weights: P38936
# Shape: (808, 808)
# Attention weights: Q92569
# Shape: (808, 808)
# Attention weights: P45850
# Shape: (808, 808)
# Attention weights: Q9ZVD5
# Shape: (926, 926)
# Attention weights: Q28399
# Shape: (926, 926)
# Attention weights: P01023
# Shape: (1476, 1476)
# Attention weights: P00812
# Shape: (1476, 1476)
# Attention weights: P34896
# Shape: (558, 558)
# Attention weights: Q8WWY3
# Shape: (558, 558)
# Attention weights: Q95017
# Shape: (558, 558)
# Attention weights: P04818
# Shape: (558, 558)
# Attention weights: O15530
# Shape: (558, 558)
# Attention weights: P68036
# Shape: (558, 558)
# Attention weights: P28702
# Shape: (558, 558)
# Attention weights: P06241
# Shape: (558, 558)
# Attention weights: P36776
# Shape: (961, 961)
# Attention weights: Q13596
# Shape: (961, 961)
# Attention weights: P04156
# Shape: (961, 961)
# Attention weights: P25911
# Shape: (961, 961)
# Attention weights: P30041
# Shape: (896, 896)
# Attention weights: Q96B02
# Shape: (896, 896)
# Attention weights: Q9Y2D1
# Shape: (896, 896)
# Attention weights: P11142
# Shape: (896, 896)
# Attention weights: P11325
# Shape: (896, 896)
# Attention weights: P27540
# Shape: (896, 896)
# Attention weights: P43405
# Shape: (896, 896)
# Attention weights: Q15024
# Shape: (896, 896)
# Attention weights: P25539
# Shape: (996, 996)
# Attention weights: Q6ZNA4
# Shape: (996, 996)
# Attention weights: P63085
# Shape: (996, 996)
# Attention weights: P16333
# Shape: (996, 996)
# Attention weights: Q9P2N6
# Shape: (906, 906)
# Attention weights: P06243
# Shape: (906, 906)
# Attention weights: P14373
# Shape: (906, 906)
# Attention weights: P46527
# Shape: (906, 906)
# Attention weights: P98170
# Shape: (1107, 1107)
# Attention weights: Q7Z3B3
# Shape: (1107, 1107)
# Attention weights: P07550
# Shape: (1107, 1107)
# Attention weights: P29350
# Shape: (1107, 1107)
# Attention weights: P32243
# Shape: (745, 745)
# Attention weights: P14859
# Shape: (745, 745)
# Attention weights: P17256
# Shape: (1322, 1322)
# Attention weights: P10503
# Shape: (1322, 1322)
# Attention weights: P61086
# Shape: (202, 202)
# Attention weights: P38398
# Shape: (1865, 1865)
# Attention weights: P10275
# Shape: (1514, 1514)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (202 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P07814
# Shape: (1514, 1514)
# Attention weights: Q9BYF1
# Shape: (807, 807)
# Attention weights: P45880
# Shape: (807, 807)
# Attention weights: P61964
# Shape: (807, 807)
# Attention weights: Q96EZ8
# Shape: (807, 807)
# Attention weights: Q5A0M4
# Shape: (1267, 1267)
# Attention weights: Q15797
# Shape: (1267, 1267)
# Attention weights: P19447
# Shape: (1267, 1267)
# Attention weights: P16885
# Shape: (1267, 1267)
# Attention weights: Q8IZH2
# Shape: (1708, 1708)
# Attention weights: Q00613
# Shape: (1708, 1708)
# Attention weights: Q06406
# Shape: (891, 891)
# Attention weights: Q13114
# Shape: (891, 891)
# Attention weights: P06733
# Shape: (891, 891)
# Attention weights: Q9NQX1
# Shape: (891, 891)
# Attention weights: P12931
# Shape: (891, 891)
# Attention weights: P40763
# Shape: (891, 891)
# Attention weights: Q0VCU1
# Shape: (891, 891)
# Attention weights: P32325
# Shape: (891, 891)
# Attention weights: P50222
# Shape: (878, 878)
# Attention weights: Q9Y6K9
# Shape: (878, 878)
# Attention weights: Q05516
# Shape: (878, 878)
# Attention weights: P00957
# Shape: (878, 878)
# Attention weights: P09546
# Shape: (1322, 1322)
# Attention weights: P0DP23
# Shape: (1322, 1322)
# Attention weights: Q60591
# Shape: (929, 929)
# Attention weights: Q9H6Y7
# Shape: (929, 929)
# Attention weights: P06709
# Shape: (929, 929)
# Attention weights: Q99816
# Shape: (929, 929)
# Attention weights: P14755
# Shape: (860, 860)
# Attention weights: Q14457
# Shape: (860, 860)
# Attention weights: P15692
# Shape: (860, 860)
# Attention weights: P06702
# Shape: (860, 860)
# Attention weights: P11980
# Shape: (860, 860)
# Attention weights: P28482
# Shape: (860, 860)
# Attention weights: P55055
# Shape: (860, 860)
# Attention weights: P13639
# Shape: (860, 860)
# Attention weights: P03069
# Shape: (913, 913)
# Attention weights: P67870
# Shape: (913, 913)
# Attention weights: Q6P9J9
# Shape: (913, 913)
# Attention weights: P09960
# Shape: (913, 913)
# Attention weights: P00546
# Shape: (429, 429)
# Attention weights: Q3Y454
# Shape: (429, 429)
# Attention weights: P00374
# Shape: (429, 429)
# Attention weights: Q6GIL8
# Shape: (429, 429)
# Attention weights: P23396
# Shape: (429, 429)
# Attention weights: Q7L0Y3
# Shape: (429, 429)
# Attention weights: O88470
# Shape: (429, 429)
# Attention weights: P11473
# Shape: (429, 429)
# Attention weights: P26639
# Shape: (725, 725)
# Attention weights: P24228
# Shape: (725, 725)
# Attention weights: P16951
# Shape: (725, 725)
# Attention weights: Q92731
# Shape: (725, 725)
# Attention weights: P00533
# Shape: (1212, 1212)
# Attention weights: P13010
# Shape: (1212, 1212)
# Attention weights: O60568
# Shape: (1212, 1212)
# Attention weights: P53350
# Shape: (1212, 1212)
# Attention weights: P19889
# Shape: (1016, 1016)
# Attention weights: Q13492
# Shape: (1016, 1016)
# Attention weights: Q96SB4
# Shape: (1016, 1016)
# Attention weights: P09874
# Shape: (1016, 1016)
# Attention weights: P50570
# Shape: (1218, 1218)
# Attention weights: Q9NQ66
# Shape: (1218, 1218)
# Attention weights: O95835
# Shape: (1218, 1218)
# Attention weights: P14921
# Shape: (1218, 1218)
# Attention weights: Q06124
# Shape: (595, 595)
# Attention weights: Q27820
# Shape: (595, 595)
# Attention weights: Q00610
# Shape: (1677, 1677)
# Attention weights: O14503
# Shape: (1677, 1677)
# Attention weights: Q12873
# Shape: (2002, 2002)
# Attention weights: Q9H4A3
# Shape: (2384, 2384)
# Attention weights: A0A0H3LHU4
# Shape: (644, 644)
# Attention weights: Q5XIM7
# Shape: (644, 644)
# Attention weights: P12956
# Shape: (644, 644)
# Attention weights: P04637
# Shape: (644, 644)
# Attention weights: P27278
# Shape: (644, 644)
# Attention weights: O43318
# Shape: (644, 644)
# Attention weights: P0A8M3
# Shape: (644, 644)
# Attention weights: Q9Y4K3
# Shape: (644, 644)
# Attention weights: Q5SW96
# Shape: (1257, 1257)
# Attention weights: P42684
# Shape: (1257, 1257)
# Attention weights: Q06559
# Shape: (1257, 1257)
# Attention weights: P04626
# Shape: (1257, 1257)
# Attention weights: F9VMT6
# Shape: (493, 493)
# Attention weights: Q8IUQ4
# Shape: (493, 493)
# Attention weights: P15291
# Shape: (493, 493)
# Attention weights: Q00987
# Shape: (493, 493)
# Attention weights: P02649
# Shape: (1292, 1292)
# Attention weights: P78362
# Shape: (1292, 1292)
# Attention weights: P13299
# Shape: (1292, 1292)
# Attention weights: P19174
# Shape: (1292, 1292)
# Attention weights: Q9HD42
# Shape: (854, 854)
# Attention weights: P19544
# Shape: (854, 854)
# Attention weights: O60341
# Shape: (854, 854)
# Attention weights: Q96EB6
# Shape: (854, 854)
# Attention weights: P07900
# Shape: (854, 854)
# Attention weights: P60953
# Shape: (854, 854)
# Attention weights: Q00534
# Shape: (854, 854)
# Attention weights: P19793
# Shape: (854, 854)
# Attention weights: Q9Y6Q9
# Shape: (1426, 1426)
# Attention weights: P03372
# Shape: (1426, 1426)
# Attention weights: P20338
# Shape: (893, 893)
# Attention weights: P84022
# Shape: (893, 893)
# Attention weights: P0A9Q7
# Shape: (893, 893)
# Attention weights: Q42525
# Shape: (893, 893)
# Attention weights: P27695
# Shape: (893, 893)
# Attention weights: P12004
# Shape: (893, 893)
# Attention weights: P08238
# Shape: (893, 893)
# Attention weights: P08237
# Shape: (893, 893)
# Attention weights: Q8WYB5
# Shape: (2075, 2075)
# Attention weights: P10276
# Shape: (1282, 1282)
# Attention weights: P08183
# Shape: (1282, 1282)
# Attention weights: P21980
# Shape: (1282, 1282)
# Attention weights: P00519
# Shape: (1282, 1282)
# Attention weights: P60010
# Shape: (377, 377)
# Attention weights: P09467
# Shape: (377, 377)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (377 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (377 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (373 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P37231
# Shape: (507, 507)
# Attention weights: P68187
# Shape: (373, 373)
# Attention weights: Q09472
# Shape: (2416, 2416)
# Attention weights: P13569
# Shape: (1482, 1482)
# Attention weights: P15336
# Shape: (1482, 1482)
# Attention weights: O22793
# Shape: (968, 968)
# Attention weights: G8JZS6
# Shape: (968, 968)
# Attention weights: G1FNI6
# Shape: (968, 968)
# Attention weights: C0LGW6
# Shape: (968, 968)
# Attention weights: C0HLV2
# Shape: (755, 755)
# Attention weights: P16402
# Shape: (755, 755)
# Attention weights: A1B198
# Shape: (755, 755)
# Attention weights: P20827
# Shape: (755, 755)
# Attention weights: A2AR95
# Shape: (755, 755)
# Attention weights: P19835
# Shape: (755, 755)
# Attention weights: O75570
# Shape: (755, 755)
# Attention weights: P0AFX0
# Shape: (755, 755)
# Attention weights: P18291
# Shape: (825, 825)
# Attention weights: G5EEG7
# Shape: (825, 825)
# Attention weights: O15033
# Shape: (825, 825)
# Attention weights: O43704
# Shape: (825, 825)
# Attention weights: O60906
# Shape: (825, 825)
# Attention weights: P15260
# Shape: (825, 825)
# Attention weights: P00423
# Shape: (825, 825)
# Attention weights: O15264
# Shape: (825, 825)
# Attention weights: P11229
# Shape: (777, 777)
# Attention weights: P08393
# Shape: (777, 777)
# Attention weights: P10613
# Shape: (777, 777)
# Attention weights: P10398
# Shape: (777, 777)
# Attention weights: P0C8E7
# Shape: (777, 777)
# Attention weights: P0AAR3
# Shape: (777, 777)
# Attention weights: O33407
# Shape: (777, 777)
# Attention weights: O95881
# Shape: (777, 777)
# Attention weights: O14529
# Shape: (1488, 1488)
# Attention weights: O14842
# Shape: (1488, 1488)
# Attention weights: O60241
# Shape: (1587, 1587)
# Attention weights: P0A870
# Shape: (1587, 1587)
# Attention weights: O75897
# Shape: (304, 304)
# Attention weights: P0AFL3
# Shape: (304, 304)
# Attention weights: P0AER0
# Shape: (304, 304)
# Attention weights: O00338
# Shape: (304, 304)
# Attention weights: P12104
# Shape: (304, 304)
# Attention weights: P0C7R1
# Shape: (304, 304)
# Attention weights: P0C0T5
# Shape: (304, 304)
# Attention weights: O00585
# Shape: (304, 304)
# Attention weights: P13001
# Shape: (867, 867)
# Attention weights: P06612
# Shape: (867, 867)
# Attention weights: O95238
# Shape: (1524, 1524)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (304 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: O60242
# Shape: (1524, 1524)
# Attention weights: P00191
# Shape: (665, 665)
# Attention weights: O96020
# Shape: (665, 665)
# Attention weights: P12530
# Shape: (665, 665)
# Attention weights: P13721
# Shape: (665, 665)
# Attention weights: O94444
# Shape: (1061, 1061)
# Attention weights: P14324
# Shape: (1061, 1061)
# Attention weights: O95399
# Shape: (1061, 1061)
# Attention weights: P13635
# Shape: (1061, 1061)
# Attention weights: P14550
# Shape: (1022, 1022)
# Attention weights: O76054
# Shape: (1022, 1022)
# Attention weights: P12960
# Shape: (1022, 1022)
# Attention weights: F1LQ48
# Shape: (1022, 1022)
# Attention weights: P14099
# Shape: (923, 923)
# Attention weights: P11859
# Shape: (923, 923)
# Attention weights: P0AF36
# Shape: (923, 923)
# Attention weights: P07148
# Shape: (923, 923)
# Attention weights: O32504
# Shape: (553, 553)
# Attention weights: P09201
# Shape: (553, 553)
# Attention weights: P0AG86
# Shape: (553, 553)
# Attention weights: P06132
# Shape: (553, 553)
# Attention weights: O15389
# Shape: (553, 553)
# Attention weights: O24146
# Shape: (553, 553)
# Attention weights: O22822
# Shape: (553, 553)
# Attention weights: P01859
# Shape: (553, 553)
# Attention weights: D2Z028
# Shape: (719, 719)
# Attention weights: P07764
# Shape: (719, 719)
# Attention weights: P10645
# Shape: (719, 719)
# Attention weights: P11672
# Shape: (719, 719)
# Attention weights: O23512
# Shape: (719, 719)
# Attention weights: P16045
# Shape: (719, 719)
# Attention weights: O60880
# Shape: (719, 719)
# Attention weights: F8WQK8
# Shape: (719, 719)
# Attention weights: P20809
# Shape: (593, 593)
# Attention weights: P18956
# Shape: (593, 593)
# Attention weights: O50202
# Shape: (593, 593)
# Attention weights: L7NCQ3
# Shape: (593, 593)
# Attention weights: O14717
# Shape: (593, 593)
# Attention weights: O43613
# Shape: (593, 593)
# Attention weights: P21375
# Shape: (593, 593)
# Attention weights: A0A0K0MJN3
# Shape: (593, 593)
# Attention weights: O43291
# Shape: (537, 537)
# Attention weights: B2UP57
# Shape: (537, 537)
# Attention weights: O13877
# Shape: (537, 537)
# Attention weights: O43278
# Shape: (537, 537)
# Attention weights: P15248
# Shape: (537, 537)
# Attention weights: O14544
# Shape: (537, 537)
# Attention weights: O15305
# Shape: (537, 537)
# Attention weights: P20783
# Shape: (537, 537)
# Attention weights: P16330
# Shape: (1078, 1078)
# Attention weights: P20676
# Shape: (1078, 1078)
# Attention weights: O14792
# Shape: (1078, 1078)
# Attention weights: O81862
# Shape: (1078, 1078)
# Attention weights: O80467
# Shape: (1645, 1645)
# Attention weights: O15054
# Shape: (1645, 1645)
# Attention weights: O75717
# Shape: (1131, 1131)
# Attention weights: O43896
# Shape: (1131, 1131)
# Attention weights: O14960
# Shape: (1131, 1131)
# Attention weights: P18075
# Shape: (1131, 1131)
# Attention weights: O34002
# Shape: (910, 910)
# Attention weights: O33283
# Shape: (910, 910)
# Attention weights: O15198
# Shape: (910, 910)
# Attention weights: P18196
# Shape: (910, 910)
# Attention weights: P0DPB6
# Shape: (910, 910)
# Attention weights: O00222
# Shape: (910, 910)
# Attention weights: H2B3G5
# Shape: (910, 910)
# Attention weights: P19221
# Shape: (910, 910)
# Attention weights: A0AVT1
# Shape: (1054, 1054)
# Attention weights: P0AEY8
# Shape: (1054, 1054)
# Attention weights: P16662
# Shape: (1054, 1054)
# Attention weights: P0AE85
# Shape: (1054, 1054)
# Attention weights: P02753
# Shape: (757, 757)
# Attention weights: O64743
# Shape: (757, 757)
# Attention weights: O54288
# Shape: (757, 757)
# Attention weights: P0AC13
# Shape: (757, 757)
# Attention weights: P04397
# Shape: (757, 757)
# Attention weights: O29976
# Shape: (757, 757)
# Attention weights: P04819
# Shape: (757, 757)
# Attention weights: O54983
# Shape: (757, 757)
# Attention weights: P05031
# Shape: (621, 621)
# Attention weights: G4NAP4
# Shape: (621, 621)
# Attention weights: P05090
# Shape: (621, 621)
# Attention weights: A6NI73
# Shape: (621, 621)
# Attention weights: A6NIH7
# Shape: (621, 621)
# Attention weights: A5KE01
# Shape: (621, 621)
# Attention weights: P05219
# Shape: (621, 621)
# Attention weights: P06106
# Shape: (621, 621)
# Attention weights: O43614
# Shape: (446, 446)
# Attention weights: P01097
# Shape: (532, 532)
# Attention weights: P00803
# Shape: (532, 532)
# Attention weights: O75324
# Shape: (532, 532)
# Attention weights: O75795
# Shape: (532, 532)
# Attention weights: P11655
# Shape: (532, 532)
# Attention weights: O75888
# Shape: (532, 532)
# Attention weights: A0A166U5H3
# Shape: (532, 532)
# Attention weights: O76021
# Shape: (532, 532)
# Attention weights: P01563
# Shape: (744, 744)
# Attention weights: O64470
# Shape: (744, 744)
# Attention weights: A0A4P8DY91
# Shape: (744, 744)
# Attention weights: O94788
# Shape: (744, 744)
# Attention weights: P07492
# Shape: (744, 744)
# Attention weights: O95727
# Shape: (744, 744)
# Attention weights: A0FKN5
# Shape: (744, 744)
# Attention weights: O95970
# Shape: (744, 744)
# Attention weights: P00724
# Shape: (888, 888)
# Attention weights: P09758
# Shape: (888, 888)
# Attention weights: P06681
# Shape: (888, 888)
# Attention weights: O43396
# Shape: (888, 888)
# Attention weights: P08638
# Shape: (888, 888)
# Attention weights: P09056
# Shape: (888, 888)
# Attention weights: P13686
# Shape: (888, 888)
# Attention weights: B4XT64
# Shape: (888, 888)
# Attention weights: P08244
# Shape: (546, 546)
# Attention weights: P09914
# Shape: (546, 546)
# Attention weights: P0AA37
# Shape: (546, 546)
# Attention weights: P08171
# Shape: (546, 546)
# Attention weights: P08168
# Shape: (546, 546)
# Attention weights: P16233
# Shape: (546, 546)
# Attention weights: P20443
# Shape: (546, 546)
# Attention weights: P11880
# Shape: (546, 546)
# Attention weights: P0ACC1
# Shape: (892, 892)
# Attention weights: P0ADS2
# Shape: (892, 892)
# Attention weights: P06983
# Shape: (892, 892)
# Attention weights: P01298
# Shape: (892, 892)
# Attention weights: P09237
# Shape: (892, 892)
# Attention weights: O81770
# Shape: (892, 892)
# Attention weights: O94806
# Shape: (892, 892)
# Attention weights: P09104
# Shape: (892, 892)
# Attention weights: O94953
# Shape: (1098, 1098)
# Attention weights: O60826
# Shape: (1098, 1098)
# Attention weights: O35250
# Shape: (1098, 1098)
# Attention weights: P08318
# Shape: (1098, 1098)
# Attention weights: P0DPD7
# Shape: (973, 973)
# Attention weights: O15537
# Shape: (973, 973)
# Attention weights: P08902
# Shape: (973, 973)
# Attention weights: O95980
# Shape: (973, 973)
# Attention weights: O14526
# Shape: (891, 891)
# Attention weights: O76095
# Shape: (891, 891)
# Attention weights: P04591
# Shape: (891, 891)
# Attention weights: O75563
# Shape: (891, 891)
# Attention weights: O60609
# Shape: (891, 891)
# Attention weights: O02372
# Shape: (891, 891)
# Attention weights: P00346
# Shape: (891, 891)
# Attention weights: P0ABI4
# Shape: (891, 891)
# Attention weights: O70394
# Shape: (1115, 1115)
# Attention weights: O08547
# Shape: (1115, 1115)
# Attention weights: P01721
# Shape: (1115, 1115)
# Attention weights: O70361
# Shape: (1115, 1115)
# Attention weights: P01709
# Shape: (120, 120)
# Attention weights: P0AAW9
# Shape: (120, 120)
# Attention weights: O96028
# Shape: (1367, 1367)
# Attention weights: O70201
# Shape: (1367, 1367)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (120 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (120 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: O75716
# Shape: (561, 561)
# Attention weights: P0A6L0
# Shape: (561, 561)
# Attention weights: O60678
# Shape: (561, 561)
# Attention weights: P0AFR2
# Shape: (561, 561)
# Attention weights: O75914
# Shape: (935, 935)
# Attention weights: O43586
# Shape: (935, 935)
# Attention weights: P08909
# Shape: (935, 935)
# Attention weights: O14939
# Shape: (935, 935)
# Attention weights: P12271
# Shape: (734, 734)
# Attention weights: O43508
# Shape: (734, 734)
# Attention weights: P17888
# Shape: (734, 734)
# Attention weights: P07327
# Shape: (734, 734)
# Attention weights: P17515
# Shape: (734, 734)
# Attention weights: P05129
# Shape: (734, 734)
# Attention weights: P13797
# Shape: (734, 734)
# Attention weights: P04279
# Shape: (734, 734)
# Attention weights: P16554
# Shape: (558, 558)
# Attention weights: P05187
# Shape: (558, 558)
# Attention weights: P06881
# Shape: (558, 558)
# Attention weights: P16297
# Shape: (558, 558)
# Attention weights: O15085
# Shape: (1524, 1524)
# Attention weights: P05696
# Shape: (1524, 1524)
# Attention weights: P06850
# Shape: (517, 517)
# Attention weights: P15202
# Shape: (517, 517)
# Attention weights: P06821
# Shape: (517, 517)
# Attention weights: P07102
# Shape: (517, 517)
# Attention weights: P00748
# Shape: (617, 617)
# Attention weights: P18239
# Shape: (617, 617)
# Attention weights: O15393
# Shape: (1665, 1665)
# Attention weights: P01027
# Shape: (1665, 1665)
# Attention weights: P14384
# Shape: (839, 839)
# Attention weights: P10987
# Shape: (839, 839)
# Attention weights: P01764
# Shape: (839, 839)
# Attention weights: O55038
# Shape: (839, 839)
# Attention weights: P01772
# Shape: (839, 839)
# Attention weights: P11551
# Shape: (839, 839)
# Attention weights: O15394
# Shape: (839, 839)
# Attention weights: P02686
# Shape: (839, 839)
# Attention weights: O49523
# Shape: (640, 640)
# Attention weights: P19934
# Shape: (640, 640)
# Attention weights: P02767
# Shape: (640, 640)
# Attention weights: O48737
# Shape: (640, 640)
# Attention weights: P03126
# Shape: (640, 640)
# Attention weights: P03485
# Shape: (640, 640)
# Attention weights: P03952
# Shape: (640, 640)
# Attention weights: P01317
# Shape: (640, 640)
# Attention weights: P09032
# Shape: (580, 580)
# Attention weights: P0DJL7
# Shape: (1293, 1293)
# Attention weights: P08487
# Shape: (1293, 1293)
# Attention weights: O61722
# Shape: (742, 742)
# Attention weights: O60759
# Shape: (742, 742)
# Attention weights: O60381
# Shape: (742, 742)
# Attention weights: O94868
# Shape: (742, 742)
# Attention weights: P0C1S8
# Shape: (742, 742)
# Attention weights: O53664
# Shape: (742, 742)
# Attention weights: P09326
# Shape: (742, 742)
# Attention weights: P07998
# Shape: (742, 742)
# Attention weights: O00451
# Shape: (474, 474)
# Attention weights: P10082
# Shape: (474, 474)
# Attention weights: P06907
# Shape: (474, 474)
# Attention weights: P00326
# Shape: (474, 474)
# Attention weights: P01597
# Shape: (474, 474)
# Attention weights: P05120
# Shape: (474, 474)
# Attention weights: P12645
# Shape: (474, 474)
# Attention weights: P13598
# Shape: (474, 474)
# Attention weights: P14091
# Shape: (630, 630)
# Attention weights: A0A075TRK9
# Shape: (630, 630)
# Attention weights: P06312
# Shape: (630, 630)
# Attention weights: P01700
# Shape: (630, 630)
# Attention weights: P19087
# Shape: (630, 630)
# Attention weights: P01704
# Shape: (630, 630)
# Attention weights: P13929
# Shape: (630, 630)
# Attention weights: P14209
# Shape: (630, 630)
# Attention weights: A6XH05
# Shape: (593, 593)
# Attention weights: P0ABV6
# Shape: (593, 593)
# Attention weights: P0CG04
# Shape: (593, 593)
# Attention weights: P18545
# Shape: (593, 593)
# Attention weights: A6NED2
# Shape: (947, 947)
# Attention weights: P14069
# Shape: (947, 947)
# Attention weights: P0C5Z0
# Shape: (947, 947)
# Attention weights: O08722
# Shape: (947, 947)
# Attention weights: P0AB58
# Shape: (1251, 1251)
# Attention weights: B2RHG1
# Shape: (1251, 1251)
# Attention weights: A6ND01
# Shape: (1251, 1251)
# Attention weights: C0LGQ5
# Shape: (1251, 1251)
# Attention weights: O00399
# Shape: (341, 341)
# Attention weights: O00757
# Shape: (341, 341)
# Attention weights: P0DOY2
# Shape: (341, 341)
# Attention weights: P00568
# Shape: (341, 341)
# Attention weights: P0A744
# Shape: (1036, 1036)
# Attention weights: P19156
# ...
# Attention weights: D9I2F9
# Shape: (1220, 1220)
# Attention weights: O43255
# Shape: (1220, 1220)
# Attention weights: P20937
# Shape: (951, 951)
# Attention weights: P08134
# Shape: (951, 951)
# Attention weights: P0DMC5
# Shape: (951, 951)
# Attention weights: P15812
# Shape: (951, 951)
# Attention weights: P12476
# Shape: (527, 527)
# Attention weights: P02042
# Shape: (527, 527)
# Attention weights: P02100
# Shape: (527, 527)
# Attention weights: P0ABB4
# Shape: (527, 527)
# Attention weights: P0ABC7
# Shape: (527, 527)
# Attention weights: P18627
# Shape: (527, 527)
# Attention weights: P12318
# Shape: (527, 527)
# Attention weights: P07288
# Shape: (527, 527)
# Attention weights: P08191
# Shape: (656, 656)
# Attention weights: P0ABE5
# Shape: (656, 656)
# Attention weights: P07363
# Shape: (656, 656)
# Attention weights: A8MT69
# Shape: (656, 656)
# Attention weights: P06169
# Shape: (656, 656)
# Attention weights: O42661
# Shape: (656, 656)
# Attention weights: P07141
# Shape: (656, 656)
# Attention weights: P09455
# Shape: (656, 656)
# Attention weights: P21243
# Shape: (642, 642)
# Attention weights: P09913
# Shape: (642, 642)
# Attention weights: P0DPK2
# Shape: (642, 642)
# Attention weights: P0A6F1
# Shape: (642, 642)
# Attention weights: P0A6S5
# Shape: (642, 642)
# Attention weights: P09446
# Shape: (642, 642)
# Attention weights: B5KM66
# Shape: (642, 642)
# Attention weights: P0A894
# Shape: (642, 642)
# Attention weights: P09086
# Shape: (481, 481)
# Attention weights: P0A903
# Shape: (481, 481)
# Attention weights: A0A2P1GIW3
# Shape: (481, 481)
# Attention weights: P0A935
# Shape: (481, 481)
# Attention weights: B5BLW5
# Shape: (579, 579)
# Attention weights: A0JNT9
# Shape: (579, 579)
# Attention weights: P06454
# Shape: (113, 113)
# Attention weights: A7KAX9
# Shape: (2089, 2089)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (113 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P0A937
# Shape: (578, 578)
# Attention weights: P0A964
# Shape: (578, 578)
# Attention weights: P0DJD3
# Shape: (578, 578)
# Attention weights: A8I4E9
# Shape: (578, 578)
# Attention weights: P0CJ48
# Shape: (578, 578)
# Attention weights: P07315
# Shape: (578, 578)
# Attention weights: P0AEJ6
# Shape: (578, 578)
# Attention weights: P04806
# Shape: (578, 578)
# Attention weights: O61667
# Shape: (971, 971)
# Attention weights: O82226
# Shape: (971, 971)
# Attention weights: O88554
# Shape: (971, 971)
# Attention weights: O88622
# Shape: (971, 971)
# Attention weights: O88844
# Shape: (787, 787)
# Attention weights: O89050
# Shape: (787, 787)
# Attention weights: O94782
# Shape: (787, 787)
# Attention weights: O60870
# Shape: (787, 787)
# Attention weights: P08240
# Shape: (640, 640)
# Attention weights: O60814
# Shape: (640, 640)
# Attention weights: O95163
# Shape: (1334, 1334)
# Attention weights: O95235
# Shape: (1334, 1334)
# Attention weights: O95257
# Shape: (510, 510)
# Attention weights: O60729
# Shape: (510, 510)
# Attention weights: O95319
# Shape: (510, 510)
# Attention weights: A0A2P1GIW2
# Shape: (510, 510)
# Attention weights: O95372
# Shape: (510, 510)
# Attention weights: O62479
# Shape: (510, 510)
# Attention weights: O76071
# Shape: (510, 510)
# Attention weights: O75365
# Shape: (510, 510)
# Attention weights: O75368
# Shape: (492, 492)
# Attention weights: O75446
# Shape: (492, 492)
# Attention weights: O74499
# Shape: (492, 492)
# Attention weights: O70624
# Shape: (492, 492)
# Attention weights: O75688
# Shape: (492, 492)
# Attention weights: P13727
# Shape: (492, 492)
# Attention weights: O75792
# Shape: (492, 492)
# Attention weights: O70435
# Shape: (492, 492)
# Attention weights: O75815
# Shape: (827, 827)
# Attention weights: P0AG30
# Shape: (827, 827)
# Attention weights: O75937
# Shape: (827, 827)
# Attention weights: O75943
# Shape: (827, 827)
# Attention weights: O75971
# Shape: (827, 827)
# Attention weights: A0A1C7D1B7
# Shape: (827, 827)
# Attention weights: O76093
# Shape: (827, 827)
# Attention weights: B2RXH2
# Shape: (827, 827)
# Attention weights: O95393
# Shape: (426, 426)
# Attention weights: O95760
# Shape: (426, 426)
# Attention weights: P01867
# Shape: (426, 426)
# Attention weights: A2A825
# Shape: (426, 426)
# Attention weights: P02309
# Shape: (639, 639)
# Attention weights: O53585
# Shape: (639, 639)
# Attention weights: O53580
# Shape: (1557, 1557)
# Attention weights: O94913
# Shape: (1557, 1557)
# Attention weights: P02942
# Shape: (725, 725)
# Attention weights: O88951
# Shape: (725, 725)
# Attention weights: O46043
# Shape: (725, 725)
# Attention weights: P03255
# Shape: (725, 725)
# Attention weights: P03452
# Shape: (725, 725)
# Attention weights: P03971
# Shape: (725, 725)
# Attention weights: O43865
# Shape: (725, 725)
# Attention weights: O35381
# Shape: (725, 725)
# Attention weights: O43765
# Shape: (593, 593)
# Attention weights: P01857
# Shape: (593, 593)
# Attention weights: O95390
# Shape: (593, 593)
# Attention weights: P01731
# Shape: (593, 593)
# Attention weights: O59734
# Shape: (593, 593)
# Attention weights: O95994
# Shape: (593, 593)
# Attention weights: O95997
# Shape: (593, 593)
# Attention weights: O96013
# Shape: (593, 593)
# Attention weights: P00257
# Shape: (524, 524)
# Attention weights: P00342
# Shape: (524, 524)
# Attention weights: P00375
# Shape: (524, 524)
# Attention weights: P00390
# Shape: (524, 524)
# Attention weights: P00572
# Shape: (524, 524)
# Attention weights: P01139
# Shape: (524, 524)
# Attention weights: P01160
# Shape: (524, 524)
# Attention weights: P01210
# Shape: (524, 524)
# Attention weights: P01225
# Shape: (427, 427)
# Attention weights: P01236
# Shape: (427, 427)
# Attention weights: P01270
# Shape: (427, 427)
# Attention weights: A1Z1Q3
# Shape: (427, 427)
# Attention weights: O55234
# Shape: (755, 755)
# Attention weights: O75175
# Shape: (755, 755)
# Attention weights: C3VPR6
# Shape: (1917, 1917)
# Attention weights: P15208
# Shape: (1374, 1374)
# Attention weights: P15151
# Shape: (1374, 1374)
# Attention weights: P14907
# Shape: (825, 825)
# Attention weights: P11124
# Shape: (825, 825)
# Attention weights: O15212
# Shape: (825, 825)
# Attention weights: P10826
# Shape: (825, 825)
# Attention weights: O88384
# Shape: (825, 825)
# Attention weights: O95154
# Shape: (825, 825)
# Attention weights: O95801
# Shape: (825, 825)
# Attention weights: O15245
# Shape: (825, 825)
# Attention weights: P00942
# Shape: (1162, 1162)
# Attention weights: P13667
# Shape: (1162, 1162)
# Attention weights: P10443
# Shape: (1162, 1162)
# Attention weights: O13034
# Shape: (1162, 1162)
# Attention weights: O09118
# Shape: (1050, 1050)
# Attention weights: P13458
# Shape: (1050, 1050)
# Attention weights: O54785
# Shape: (1050, 1050)
# Attention weights: O75112
# Shape: (1050, 1050)
# Attention weights: O73790
# Shape: (567, 567)
# Attention weights: O70209
# Shape: (567, 567)
# Attention weights: O64903
# Shape: (567, 567)
# Attention weights: O08807
# Shape: (567, 567)
# Attention weights: P03612
# Shape: (567, 567)
# Attention weights: O14036
# Shape: (567, 567)
# Attention weights: P11836
# Shape: (567, 567)
# Attention weights: P18014
# Shape: (567, 567)
# Attention weights: O08838
# Shape: (685, 685)
# Attention weights: P12272
# Shape: (685, 685)
# Attention weights: P12670
# Shape: (685, 685)
# Attention weights: P13199
# Shape: (685, 685)
# Attention weights: O60684
# Shape: (685, 685)
# Attention weights: D6RGH6
# Shape: (685, 685)
# Attention weights: P15700
# Shape: (685, 685)
# Attention weights: O75144
# Shape: (685, 685)
# Attention weights: M1V4Y8
# Shape: (804, 804)
# Attention weights: P18433
# Shape: (804, 804)
# Attention weights: P20592
# Shape: (804, 804)
# Attention weights: P20065
# Shape: (804, 804)
# Attention weights: P19880
# Shape: (1461, 1461)
# Attention weights: A2ABV5
# Shape: (1461, 1461)
# Attention weights: P19784
# Shape: (746, 746)
# Attention weights: P18708
# Shape: (746, 746)
# Attention weights: B9EHT4
# Shape: (746, 746)
# Attention weights: P18509
# Shape: (746, 746)
# Attention weights: C6KRN1
# Shape: (746, 746)
# Attention weights: O00175
# Shape: (746, 746)
# Attention weights: O14879
# Shape: (746, 746)
# Attention weights: G7JEE5
# Shape: (746, 746)
# Attention weights: P14868
# Shape: (503, 503)
# Attention weights: P0AES9
# Shape: (503, 503)
# Attention weights: F5HF68
# Shape: (451, 451)
# Attention weights: O14187
# Shape: (2365, 2365)
# Attention weights: O14520
# Shape: (344, 344)
# Attention weights: O75031
# Shape: (344, 344)
# Attention weights: P16152
# Shape: (1495, 1495)
# Attention weights: F4JW79
# Shape: (1495, 1495)
# Attention weights: O74966
# Shape: (1498, 1498)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (344 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (344 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: O15056
# Shape: (1498, 1498)
# Attention weights: O54924
# Shape: (784, 784)
# Attention weights: O09061
# Shape: (784, 784)
# Attention weights: P16568
# Shape: (784, 784)
# Attention weights: O35627
# Shape: (784, 784)
# Attention weights: O15055
# Shape: (1257, 1257)
# Attention weights: O00182
# Shape: (1257, 1257)
# Attention weights: O14368
# Shape: (1257, 1257)
# Attention weights: P10810
# Shape: (1257, 1257)
# Attention weights: E7EZF3
# Shape: (903, 903)
# Attention weights: P06993
# Shape: (903, 903)
# Attention weights: P07395
# Shape: (903, 903)
# Attention weights: P0DMC3
# Shape: (903, 903)
# Attention weights: O96033
# Shape: (903, 903)
# Attention weights: P0ACN4
# Shape: (903, 903)
# Attention weights: P00560
# Shape: (903, 903)
# Attention weights: P0CY29
# Shape: (903, 903)
# Attention weights: O18334
# Shape: (803, 803)
# Attention weights: P08048
# Shape: (803, 803)
# Attention weights: O75129
# Shape: (1341, 1341)
# Attention weights: O00910
# Shape: (1341, 1341)
# Attention weights: P0ABB0
# Shape: (515, 515)
# Attention weights: O22287
# Shape: (515, 515)
# Attention weights: P08312
# Shape: (515, 515)
# Attention weights: C8VTS4
# Shape: (515, 515)
# Attention weights: O23530
# Shape: (1439, 1439)
# Attention weights: P04053
# Shape: (1439, 1439)
# Attention weights: P05451
# Shape: (665, 665)
# Attention weights: P0A6E6
# Shape: (665, 665)
# Attention weights: P0A6Y1
# Shape: (665, 665)
# Attention weights: P06704
# Shape: (665, 665)
# Attention weights: P07636
# Shape: (665, 665)
# Attention weights: O00472
# Shape: (665, 665)
# Attention weights: P08118
# Shape: (665, 665)
# Attention weights: P0AFF6
# Shape: (665, 665)
# Attention weights: P08572
# Shape: (1714, 1714)
# Attention weights: O95833
# Shape: (1714, 1714)
# Attention weights: P0DPK5
# Shape: (647, 647)
# Attention weights: P21374
# Shape: (647, 647)
# Attention weights: P0DTD2
# Shape: (647, 647)
# Attention weights: P0AGC3
# Shape: (647, 647)
# Attention weights: O75344
# Shape: (647, 647)
# Attention weights: O95484
# Shape: (647, 647)
# Attention weights: P0DTC5
# Shape: (647, 647)
# Attention weights: O00253
# Shape: (647, 647)
# Attention weights: O94316
# Shape: (1247, 1247)
# Attention weights: P10300
# Shape: (1247, 1247)
# Attention weights: P10493
# Shape: (1247, 1247)
# Attention weights: O95273
# Shape: (1247, 1247)
# Attention weights: D3ZMK9
# Shape: (1370, 1370)
# Attention weights: P16219
# Shape: (1370, 1370)
# Attention weights: O88867
# Shape: (480, 480)
# Attention weights: C4M4P4
# Shape: (480, 480)
# Attention weights: O53581
# Shape: (1393, 1393)
# Attention weights: O75694
# Shape: (1393, 1393)
# Attention weights: P0A0M0
# Shape: (243, 243)
# Attention weights: P07014
# Shape: (243, 243)
# Attention weights: P0C7P0
# Shape: (243, 243)
# Attention weights: O88273
# Shape: (243, 243)
# Attention weights: O75525
# Shape: (1102, 1102)
# Attention weights: P07358
# Shape: (1102, 1102)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (243 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (243 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (243 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (243 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P03615
# Shape: (1102, 1102)
# Attention weights: O94875
# Shape: (1102, 1102)
# Attention weights: O75317
# Shape: (1259, 1259)
# Attention weights: P21583
# Shape: (1259, 1259)
# Attention weights: A0A0B5LB55
# Shape: (1259, 1259)
# Attention weights: O75334
# Shape: (1259, 1259)
# Attention weights: O75347
# Shape: (269, 269)
# Attention weights: P01189
# Shape: (269, 269)
# Attention weights: O89093
# Shape: (269, 269)
# Attention weights: P00684
# Shape: (269, 269)
# Attention weights: P17562
# Shape: (395, 395)
# Attention weights: P08169
# Shape: (2501, 2501)
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (269 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (269 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (269 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (269 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# /data/users/rodalex/software/miniconda3/envs/prot_env/lib/python3.9/site-packages/sklearn/random_projection.py:411: DataDimensionalityWarning: The number of components is higher than the number of features: n_features < n_components (395 < 400).The dimensionality of the problem will not be reduced.
#   warnings.warn(
# Attention weights: P01031
# Shape: (1678, 1678)
# Attention weights: A7IZE9
# Shape: (1678, 1678)
# Attention weights: P00894
# Shape: (679, 679)
# Attention weights: P16435
# Shape: (679, 679)
# Attention weights: P15926
# Shape: (1648, 1648)
# Attention weights: O94649
# Shape: (1648, 1648)
# Attention weights: P09956
# Shape: (577, 577)
# Attention weights: P04696
# Shape: (577, 577)
# Attention weights: O08583
# Shape: (577, 577)
# Attention weights: P14902
# Shape: (577, 577)
# Attention weights: O95631
# Shape: (606, 606)
# Attention weights: O95361
# Shape: (606, 606)
# Attention weights: O55164
# Shape: (2056, 2056)
# Attention weights: O96018
# Shape: (673, 673)
# Attention weights: O60504
# Shape: (673, 673)
# Attention weights: O43924
# Shape: (673, 673)
# Attention weights: O76927
# Shape: (673, 673)
# Attention weights: P10768
# Shape: (673, 673)
# Attention weights: O95149
# Shape: (673, 673)
# Attention weights: O95429
# Shape: (673, 673)
# Attention weights: P0AFX7
# Shape: (673, 673)
# Attention weights: O95704
# Shape: (488, 488)
# Attention weights: P0AC19
# Shape: (488, 488)

# %%
# Create ProteinDataset instance
base_dataset = ProteinDataset(df, embeddings, attention_weights, solve_inconsistencies=True)
embeddings = np.array(base_dataset.get_embeddings())
att_weights = base_dataset.get_attention_weights()

print(f"ProteinDataset created →embeddings: {len(embeddings)}, attention_weights: {len(att_weights)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Create ProteinDataset instance
# ----> 2 base_dataset = ProteinDataset(df, embeddings, attention_weights, solve_inconsistencies=True)
#       3 embeddings = np.array(base_dataset.get_embeddings())
#       4 att_weights = base_dataset.get_attention_weights()
#
# NameError: name 'ProteinDataset' is not defined

# %%
print(f"Attention weights shape: {att_weights[1].shape}")
# Out:
# Attention weights shape: (298116,)

# %%
# Choose configs to compare
projection_methods = {
    "by_prot": apply_random_projection_by_prot,
    "global": apply_random_projection_globaly
}

n_components_proj = 500  # Dimensionality after projection
n_clusters = 3  # For KMeans

def analyze_representation(att_data, label, show_tsne=True):
    print(f"\n===== Analyzing representation: {label} =====")

    # PCA
    pca = PCA(n_components=0.95)
    att_pca = pca.fit_transform(att_data)
    explained_variance = np.sum(pca.explained_variance_ratio_)
    print(f"PCA (95% variance) → shape: {att_pca.shape}, explained variance: {explained_variance:.4f}")

    # Plot PCA
    plt.figure(figsize=(8, 6))
    plt.scatter(att_pca[:, 0], att_pca[:, 1], alpha=0.6)
    plt.title(f'PCA 2D Projection ({label})')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # t-SNE
    if show_tsne:
        tsne = TSNE(n_components=2, perplexity=30, random_state=42)
        att_tsne = tsne.fit_transform(att_data)
        plt.figure(figsize=(8, 6))
        plt.scatter(att_tsne[:, 0], att_tsne[:, 1], alpha=0.6)
        plt.title(f't-SNE 2D Projection ({label})')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # KMeans
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(att_data)
    sil_score = silhouette_score(att_data, kmeans.labels_)
    print(f"KMeans Silhouette Score ({n_clusters} clusters): {sil_score:.4f}")

    # Correlation heatmap
    corr = np.corrcoef(att_data, rowvar=False)
    plt.figure(figsize=(12, 8))
    sns.heatmap(corr, cmap='coolwarm')
    plt.title(f'Correlation Heatmap ({label})')
    plt.tight_layout()
    plt.show()


# Run analysis for both projection methods
for method_name, projection_func in projection_methods.items():
    print(f"\n>>> Applying {method_name} random projection...")

    if method_name == "by_prot":
        projected = np.vstack(list(attention_weights_by_prot.values()))
    else:
        projected = projection_func(attention_weights, n_components=n_components_proj)


    analyze_representation(projected, label=f"{method_name} projection")
# Out:
# >>> Applying by_prot random projection...
#
# ===== Analyzing representation: by_prot projection =====
# PCA (95% variance) → shape: (1001318, 330), explained variance: 0.9508
