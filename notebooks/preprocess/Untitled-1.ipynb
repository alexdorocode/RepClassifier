# %%
# %cd ../../DATASETS/raw_data
# Out:
# [Errno 2] No such file or directory: '../../DATASETS/raw_data'
# /Users/alexdominguez/Documents/GitHub/TFM/RepClassifier/notebooks/preprocess

# %%
import pandas as pd

uniprot_ids = pd.read_csv('uniprot_ids.csv')
