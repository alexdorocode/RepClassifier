# %%
import os
import sys

# Set the working directory to the project root (RepClassifier)
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
os.chdir(project_root)

# Optionally, add the project root to the Python path
if project_root not in sys.path:
    sys.path.append(project_root)

print(f"Working directory set to: {os.getcwd()}")
# Out:
# Working directory set to: /Users/alexdominguez/Documents/GitHub/TFM/RepClassifier

# %%
# PATHS
GeOKG_DIR = os.path.join("..", "MODELS", "goa_embedding")
GeOKG_weights = os.path.join(GeOKG_DIR, "GeOKG_50dim.npy")

# %%
import numpy as np

# Load embeddings
embedding_matrix = np.load(GeOKG_weights)  # shape: (num_entities, 200)

# Load entity2id mapping
entity2id = {}
with open("entity2id.txt", "r") as f:
    for line in f:
        name, idx = line.strip().split()
        entity2id[name] = int(idx)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 # Load entity2id mapping
#       7 entity2id = {}
# ----> 8 with open("entity2id.txt", "r") as f:
#       9     for line in f:
#      10         name, idx = line.strip().split()
#
# File ~/opt/anaconda3/envs/prott5-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'entity2id.txt'
